# %% [markdown]
# # 생성적 적대 신경망(Generative Adversarial Networks)[GAN]:
# 딥러닝의 원리를 이용하여 가상 이미지를 생성하는 알고리즘
#
# - adversarial은 GAN 알고리즘을 잘 설명하는 단어; 생성자(Generator)와 판별자(Discriminator)이 적대적 경합을 하기 때문이다.

# %% [markdown]
# # DCGAN(Deep Convolutional GAN):
# 페이스북 AI 연구팀이 발표한 CNN을 GAN에 적용한 알고리즘

# %%
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, Flatten, Reshape, Activation, BatchNormalization, LeakyReLU, Conv2D, UpSampling2D
from keras.datasets import mnist

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# - 배치 정규화(Batch Normalization): 평균이 0, 분산이 1이 되도록 재배치하는 것
#
#
# > 다음 층으로 입력될 값을 일정하게 재배치한다. 이를 통해 층의 개수가 늘어나도 안정적인 학습을 진행하게 한다.

# %% [markdown]
# - LeakyReLU : 기존 렐루 함수에서 x값이 음수이면 무조건 0이 되어 뉴런이 일찍 소실되는 단점을 보완 (LeakyReLU(0.2)은 0보다 작으면 0.2를 곱하라는 의미)

# %%
# 생성자 모델
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))   # 7*7인 이유는 (1),(2)에서 두배가 되기 때문 (128과 input_dim은 임의의 숫자)
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))                                       # 컨볼루션 레이어가 받아들일 수 있는 형태로 변경 (괄호 갯수 주의)
generator.add(UpSampling2D())                                             #(1) 7*7 -> 14*14
generator.add(Conv2D(64, kernel_size=5, padding='same'))                  #padding='same' 모자라는 부분을 0으로 채워준다
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))                                 # 기존 렐루는 GAN에서 불안정해 변형한 LeakyReLU 사용
generator.add(UpSampling2D())                                             #(2) 14*14 -> 28*28
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))# tanh를 쓰면 출력이 -1 ~ 1이 된다. MNIST 손글씨 픽셀 범위도 -1 ~ 1로 맞추면 판별조건이 갖춰진다.

# %% [markdown]
# UpSampling2D를 이용하여 이미지 크기를 점점 늘려가는 것이 DCGAN의 특징이다.
# - UpSampling2D와 Conv2D가 합쳐진 **Conv2DTranspose()** 함수를 이용하면 된다.

# %%
# 판별자 모델
# 컨볼루션 신경망 구조를 그대로 사용
# 판별자는 학습하지 않으므로 가중치를 저장하는 학습기능을 꺼야함
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding='same')) #strides를 사용하면 드롭아웃이나 풀링 효과가 생긴다.
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding='same'))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')             
discriminator.trainable = False                                                 # 학습기능 off

# %%
# 생성자와 판별자 모델을 연결시키는 gan 모델
ginput = Input(shape=(100,))                                                    # 랜덤한 100개의 벡터를 입력
dis_output = discriminator(generator(ginput))                                   # 생성자가 만든 것을 판별자에 입력한 것
gan = Model(ginput, dis_output)                                                 # 생성자와 판별자 연결
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 100)]             0
#
#  sequential_14 (Sequential)  (None, 28, 28, 1)         865281
#
#  sequential_15 (Sequential)  (None, 1)                 212865
#
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
# 신경망 실행 함수
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기(앞서 사용한 MNIST 재사용, 테스트 과정은 필요 없고, 이미지만 사용하기에 X_train만 호출)
  (X_train,_), (_, _) = mnist.load_data()
  X_tain = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')

  # 127.5를 뺀 후 127.5로 나누어 -1~1 사의 값으로 변경
  X_train = (X_train - 127.5) / 127.5

  true = np.ones((batch_size, 1)) #모두 1인 레이블을 가진 배열. batch_size 길이 만큼 생성
  fake = np.zeros((batch_size, 1))  #가상의 이미지들

  for i in range(epoch):
    # 실제 데이터를 판별자에 입력하는 부분
    idx = np.random.randint(0, X_train.shape[0], batch_size)                    #np.random.randint(a,b,c) a부터 b까지 숫자중 하나를 c번 반복해서 가져오라
    imgs = X_train[idx]
    d_loss_real = discriminator.train_on_batch(imgs, true)                      #train_on_batch(x,y) 입력값x와 레이블y를 받아서 한번 학습을 실시해 모델을 업데이트한다.

    # 가상 이미지를 판별자에 입력
    noise = np.random.normal(0, 1, (batch_size, 100))                           #정수가 아니므로 .normal / (batch_size, 100): batch_size 만큼 100열을 뽑아라
    gen_imgs = generator.predict(noise)
    d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

    #판별자와 생성자의 오차 계산
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
    g_loss = gan.train_on_batch(noise, true)

    print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

    # 중간 과정을 이미지로 저장하는 부분. (정해진 인터벌만큼 학습되면 그때 만든 이미지를 gan_images 폴더에 저장하라는 것)
    if i % saving_interval == 0:
        #r, c = 5, 5
        noise = np.random.normal(0, 1, (25, 100))
        gen_imgs = generator.predict(noise)

        # Rescale images 0 - 1
        gen_imgs = 0.5 * gen_imgs + 0.5

        fig, axs = plt.subplots(5, 5)
        count = 0
        for j in range(5):
          for k in range(5):
            axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
            axs[j, k].axis('off')
            count += 1
        fig.savefig("./gan_mnist_%d.png" % i)

# %%
# 2000번 반복(+1주의), 배치 크기는 32, 200번마다 결과 저장
gan_train(2001, 32, 200)
# Out:
# 1/1 [==============================] - 0s 83ms/step
# epoch:0  d_loss:0.5693  g_loss:0.1313
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 86ms/step
# epoch:1  d_loss:0.5471  g_loss:0.1856
# 1/1 [==============================] - 0s 84ms/step
# epoch:2  d_loss:0.4938  g_loss:0.3618
# 1/1 [==============================] - 0s 81ms/step
# epoch:3  d_loss:0.4464  g_loss:0.5995
# 1/1 [==============================] - 0s 83ms/step
# epoch:4  d_loss:0.4654  g_loss:0.7983
# 1/1 [==============================] - 0s 83ms/step
# epoch:5  d_loss:0.5220  g_loss:0.7947
# 1/1 [==============================] - 0s 84ms/step
# epoch:6  d_loss:0.6580  g_loss:0.7240
# 1/1 [==============================] - 0s 87ms/step
# epoch:7  d_loss:0.8090  g_loss:0.5609
# 1/1 [==============================] - 0s 83ms/step
# epoch:8  d_loss:0.7595  g_loss:0.5173
# 1/1 [==============================] - 0s 95ms/step
# epoch:9  d_loss:0.7743  g_loss:0.4674
# 1/1 [==============================] - 0s 82ms/step
# epoch:10  d_loss:0.6384  g_loss:0.5181
# 1/1 [==============================] - 0s 83ms/step
# epoch:11  d_loss:0.5122  g_loss:0.5814
# 1/1 [==============================] - 0s 84ms/step
# epoch:12  d_loss:0.4801  g_loss:0.5943
# 1/1 [==============================] - 0s 82ms/step
# epoch:13  d_loss:0.4903  g_loss:0.6180
# 1/1 [==============================] - 0s 83ms/step
# epoch:14  d_loss:0.4812  g_loss:0.5710
# 1/1 [==============================] - 0s 83ms/step
# epoch:15  d_loss:0.4619  g_loss:0.5084
# 1/1 [==============================] - 0s 90ms/step
# epoch:16  d_loss:0.4222  g_loss:0.4526
# 1/1 [==============================] - 0s 88ms/step
# epoch:17  d_loss:0.4133  g_loss:0.6171
# 1/1 [==============================] - 0s 85ms/step
# epoch:18  d_loss:0.3617  g_loss:0.6944
# 1/1 [==============================] - 0s 89ms/step
# epoch:19  d_loss:0.3280  g_loss:0.6833
# 1/1 [==============================] - 0s 82ms/step
# epoch:20  d_loss:0.3077  g_loss:0.6479
# 1/1 [==============================] - 0s 82ms/step
# epoch:21  d_loss:0.2515  g_loss:0.5609
# 1/1 [==============================] - 0s 88ms/step
# epoch:22  d_loss:0.2035  g_loss:0.4961
# 1/1 [==============================] - 0s 93ms/step
# epoch:23  d_loss:0.2177  g_loss:0.5724
# 1/1 [==============================] - 0s 86ms/step
# epoch:24  d_loss:0.2016  g_loss:0.5025
# 1/1 [==============================] - 0s 85ms/step
# epoch:25  d_loss:0.4232  g_loss:0.2904
# 1/1 [==============================] - 0s 84ms/step
# epoch:26  d_loss:0.4801  g_loss:0.1390
# 1/1 [==============================] - 0s 87ms/step
# epoch:27  d_loss:1.0904  g_loss:0.1517
# 1/1 [==============================] - 0s 87ms/step
# epoch:28  d_loss:1.0800  g_loss:0.4780
# 1/1 [==============================] - 0s 83ms/step
# epoch:29  d_loss:1.1452  g_loss:0.8046
# 1/1 [==============================] - 0s 88ms/step
# epoch:30  d_loss:1.0755  g_loss:0.8187
# 1/1 [==============================] - 0s 94ms/step
# epoch:31  d_loss:0.7810  g_loss:0.7584
# 1/1 [==============================] - 0s 85ms/step
# epoch:32  d_loss:0.4817  g_loss:0.8604
# 1/1 [==============================] - 0s 83ms/step
# epoch:33  d_loss:0.3293  g_loss:1.0130
# 1/1 [==============================] - 0s 84ms/step
# epoch:34  d_loss:0.1654  g_loss:1.7128
# 1/1 [==============================] - 0s 81ms/step
# epoch:35  d_loss:0.1119  g_loss:2.2443
# 1/1 [==============================] - 0s 82ms/step
# epoch:36  d_loss:0.0949  g_loss:2.9189
# 1/1 [==============================] - 0s 82ms/step
# epoch:37  d_loss:0.0895  g_loss:2.5576
# 1/1 [==============================] - 0s 86ms/step
# epoch:38  d_loss:0.0522  g_loss:2.5420
# 1/1 [==============================] - 0s 86ms/step
# epoch:39  d_loss:0.0425  g_loss:2.3536
# 1/1 [==============================] - 0s 83ms/step
# epoch:40  d_loss:0.0640  g_loss:2.1446
# 1/1 [==============================] - 0s 87ms/step
# epoch:41  d_loss:0.1047  g_loss:2.1866
# 1/1 [==============================] - 0s 82ms/step
# epoch:42  d_loss:0.0996  g_loss:2.4512
# 1/1 [==============================] - 0s 87ms/step
# epoch:43  d_loss:0.1200  g_loss:2.9649
# 1/1 [==============================] - 0s 87ms/step
# epoch:44  d_loss:0.1017  g_loss:3.0176
# 1/1 [==============================] - 0s 92ms/step
# epoch:45  d_loss:0.1272  g_loss:2.5994
# 1/1 [==============================] - 0s 82ms/step
# epoch:46  d_loss:0.1532  g_loss:2.2188
# 1/1 [==============================] - 0s 88ms/step
# epoch:47  d_loss:0.3592  g_loss:2.9641
# 1/1 [==============================] - 0s 82ms/step
# epoch:48  d_loss:0.6034  g_loss:2.8562
# 1/1 [==============================] - 0s 100ms/step
# epoch:49  d_loss:0.3363  g_loss:3.3228
# 1/1 [==============================] - 0s 99ms/step
# epoch:50  d_loss:0.4416  g_loss:3.3605
# 1/1 [==============================] - 0s 86ms/step
# epoch:51  d_loss:0.3296  g_loss:2.7697
# 1/1 [==============================] - 0s 84ms/step
# epoch:52  d_loss:0.4222  g_loss:2.5674
# 1/1 [==============================] - 0s 83ms/step
# epoch:53  d_loss:0.4209  g_loss:2.0206
# 1/1 [==============================] - 0s 86ms/step
# epoch:54  d_loss:0.3995  g_loss:1.8147
# 1/1 [==============================] - 0s 89ms/step
# epoch:55  d_loss:0.2879  g_loss:2.2917
# 1/1 [==============================] - 0s 84ms/step
# epoch:56  d_loss:0.2473  g_loss:2.4721
# 1/1 [==============================] - 0s 83ms/step
# epoch:57  d_loss:0.3377  g_loss:2.7084
# 1/1 [==============================] - 0s 86ms/step
# epoch:58  d_loss:0.3788  g_loss:1.9865
# 1/1 [==============================] - 0s 94ms/step
# epoch:59  d_loss:0.3474  g_loss:1.7092
# 1/1 [==============================] - 0s 90ms/step
# epoch:60  d_loss:0.3442  g_loss:2.0786
# 1/1 [==============================] - 0s 85ms/step
# epoch:61  d_loss:0.3270  g_loss:2.5601
# 1/1 [==============================] - 0s 82ms/step
# epoch:62  d_loss:0.2624  g_loss:2.9083
# 1/1 [==============================] - 0s 90ms/step
# epoch:63  d_loss:0.3397  g_loss:2.6891
# 1/1 [==============================] - 0s 82ms/step
# epoch:64  d_loss:0.3869  g_loss:1.9885
# 1/1 [==============================] - 0s 81ms/step
# epoch:65  d_loss:0.2864  g_loss:2.2817
# 1/1 [==============================] - 0s 84ms/step
# epoch:66  d_loss:0.3878  g_loss:2.3702
# 1/1 [==============================] - 0s 82ms/step
# epoch:67  d_loss:0.2377  g_loss:2.8718
# 1/1 [==============================] - 0s 87ms/step
# epoch:68  d_loss:0.3135  g_loss:2.5266
# 1/1 [==============================] - 0s 82ms/step
# epoch:69  d_loss:0.3014  g_loss:2.9410
# 1/1 [==============================] - 0s 86ms/step
# epoch:70  d_loss:0.3121  g_loss:2.6925
# 1/1 [==============================] - 0s 88ms/step
# epoch:71  d_loss:0.3527  g_loss:2.4936
# 1/1 [==============================] - 0s 90ms/step
# epoch:72  d_loss:0.4410  g_loss:2.7608
# 1/1 [==============================] - 0s 83ms/step
# epoch:73  d_loss:0.2840  g_loss:2.5891
# 1/1 [==============================] - 0s 86ms/step
# epoch:74  d_loss:0.2506  g_loss:3.0579
# 1/1 [==============================] - 0s 92ms/step
# epoch:75  d_loss:0.2789  g_loss:2.9067
# 1/1 [==============================] - 0s 84ms/step
# epoch:76  d_loss:0.2413  g_loss:3.1211
# 1/1 [==============================] - 0s 86ms/step
# epoch:77  d_loss:0.4559  g_loss:2.4042
# 1/1 [==============================] - 0s 87ms/step
# epoch:78  d_loss:0.3336  g_loss:2.5754
# 1/1 [==============================] - 0s 84ms/step
# epoch:79  d_loss:0.2099  g_loss:2.9578
# 1/1 [==============================] - 0s 89ms/step
# epoch:80  d_loss:0.3228  g_loss:2.6109
# 1/1 [==============================] - 0s 84ms/step
# epoch:81  d_loss:0.4370  g_loss:2.0738
# 1/1 [==============================] - 0s 84ms/step
# epoch:82  d_loss:0.4271  g_loss:1.7905
# 1/1 [==============================] - 0s 86ms/step
# epoch:83  d_loss:0.2737  g_loss:2.1500
# 1/1 [==============================] - 0s 87ms/step
# epoch:84  d_loss:0.3583  g_loss:2.8265
# 1/1 [==============================] - 0s 82ms/step
# epoch:85  d_loss:0.3168  g_loss:2.8174
# 1/1 [==============================] - 0s 86ms/step
# epoch:86  d_loss:0.3321  g_loss:3.1981
# 1/1 [==============================] - 0s 85ms/step
# epoch:87  d_loss:0.4419  g_loss:2.3395
# 1/1 [==============================] - 0s 82ms/step
# epoch:88  d_loss:0.4115  g_loss:2.2277
# 1/1 [==============================] - 0s 83ms/step
# epoch:89  d_loss:0.4159  g_loss:1.7375
# 1/1 [==============================] - 0s 83ms/step
# epoch:90  d_loss:0.4750  g_loss:2.0819
# 1/1 [==============================] - 0s 87ms/step
# epoch:91  d_loss:0.4320  g_loss:2.1422
# 1/1 [==============================] - 0s 87ms/step
# epoch:92  d_loss:0.5734  g_loss:2.2107
# 1/1 [==============================] - 0s 95ms/step
# epoch:93  d_loss:0.5764  g_loss:1.7847
# 1/1 [==============================] - 0s 82ms/step
# epoch:94  d_loss:0.5032  g_loss:1.6704
# 1/1 [==============================] - 0s 82ms/step
# epoch:95  d_loss:0.5276  g_loss:1.5795
# 1/1 [==============================] - 0s 85ms/step
# epoch:96  d_loss:0.4685  g_loss:2.1975
# 1/1 [==============================] - 0s 82ms/step
# epoch:97  d_loss:0.6626  g_loss:1.6123
# 1/1 [==============================] - 0s 81ms/step
# epoch:98  d_loss:0.7228  g_loss:1.4912
# 1/1 [==============================] - 0s 83ms/step
# epoch:99  d_loss:0.7082  g_loss:0.9819
# 1/1 [==============================] - 0s 84ms/step
# epoch:100  d_loss:0.7162  g_loss:1.2142
# 1/1 [==============================] - 0s 82ms/step
# epoch:101  d_loss:0.4919  g_loss:1.5998
# 1/1 [==============================] - 0s 91ms/step
# epoch:102  d_loss:0.5328  g_loss:1.9906
# 1/1 [==============================] - 0s 87ms/step
# epoch:103  d_loss:0.5314  g_loss:1.9695
# 1/1 [==============================] - 0s 84ms/step
# epoch:104  d_loss:0.6179  g_loss:1.3373
# 1/1 [==============================] - 0s 82ms/step
# epoch:105  d_loss:0.6366  g_loss:1.0009
# 1/1 [==============================] - 0s 92ms/step
# epoch:106  d_loss:0.5193  g_loss:1.2761
# 1/1 [==============================] - 0s 83ms/step
# epoch:107  d_loss:0.5524  g_loss:1.2942
# 1/1 [==============================] - 0s 82ms/step
# epoch:108  d_loss:0.4938  g_loss:1.2706
# 1/1 [==============================] - 0s 83ms/step
# epoch:109  d_loss:0.5428  g_loss:1.2556
# 1/1 [==============================] - 0s 85ms/step
# epoch:110  d_loss:0.5575  g_loss:1.0052
# 1/1 [==============================] - 0s 91ms/step
# epoch:111  d_loss:0.5680  g_loss:0.6224
# 1/1 [==============================] - 0s 85ms/step
# epoch:112  d_loss:0.6723  g_loss:0.7132
# 1/1 [==============================] - 0s 83ms/step
# epoch:113  d_loss:0.7055  g_loss:0.6176
# 1/1 [==============================] - 0s 88ms/step
# epoch:114  d_loss:0.7415  g_loss:0.5493
# 1/1 [==============================] - 0s 85ms/step
# epoch:115  d_loss:0.5833  g_loss:0.7610
# 1/1 [==============================] - 0s 85ms/step
# epoch:116  d_loss:0.6194  g_loss:0.7204
# 1/1 [==============================] - 0s 90ms/step
# epoch:117  d_loss:0.7276  g_loss:0.6328
# 1/1 [==============================] - 0s 85ms/step
# epoch:118  d_loss:0.7355  g_loss:0.7513
# 1/1 [==============================] - 0s 82ms/step
# epoch:119  d_loss:0.7376  g_loss:0.7735
# 1/1 [==============================] - 0s 84ms/step
# epoch:120  d_loss:0.6530  g_loss:0.9215
# 1/1 [==============================] - 0s 90ms/step
# epoch:121  d_loss:0.5554  g_loss:1.2542
# 1/1 [==============================] - 0s 86ms/step
# epoch:122  d_loss:0.6972  g_loss:1.4224
# 1/1 [==============================] - 0s 82ms/step
# epoch:123  d_loss:0.6458  g_loss:1.2425
# 1/1 [==============================] - 0s 87ms/step
# epoch:124  d_loss:0.6340  g_loss:1.5795
# 1/1 [==============================] - 0s 90ms/step
# epoch:125  d_loss:0.4719  g_loss:1.6845
# 1/1 [==============================] - 0s 85ms/step
# epoch:126  d_loss:0.5991  g_loss:1.4458
# 1/1 [==============================] - 0s 82ms/step
# epoch:127  d_loss:0.7281  g_loss:1.4338
# 1/1 [==============================] - 0s 84ms/step
# epoch:128  d_loss:0.5545  g_loss:1.4134
# 1/1 [==============================] - 0s 86ms/step
# epoch:129  d_loss:0.5254  g_loss:1.4373
# 1/1 [==============================] - 0s 82ms/step
# epoch:130  d_loss:0.6262  g_loss:1.3327
# 1/1 [==============================] - 0s 82ms/step
# epoch:131  d_loss:0.7524  g_loss:1.3061
# 1/1 [==============================] - 0s 88ms/step
# epoch:132  d_loss:0.7542  g_loss:0.9323
# 1/1 [==============================] - 0s 81ms/step
# epoch:133  d_loss:0.7410  g_loss:0.7560
# 1/1 [==============================] - 0s 84ms/step
# epoch:134  d_loss:0.5146  g_loss:0.8825
# 1/1 [==============================] - 0s 82ms/step
# epoch:135  d_loss:0.5664  g_loss:1.1674
# 1/1 [==============================] - 0s 87ms/step
# epoch:136  d_loss:0.5369  g_loss:1.2045
# 1/1 [==============================] - 0s 83ms/step
# epoch:137  d_loss:0.4096  g_loss:1.5571
# 1/1 [==============================] - 0s 84ms/step
# epoch:138  d_loss:0.3027  g_loss:1.4619
# 1/1 [==============================] - 0s 99ms/step
# epoch:139  d_loss:0.4696  g_loss:1.6014
# 1/1 [==============================] - 0s 158ms/step
# epoch:140  d_loss:0.5325  g_loss:1.6170
# 1/1 [==============================] - 0s 157ms/step
# epoch:141  d_loss:0.4458  g_loss:1.9657
# 1/1 [==============================] - 0s 88ms/step
# epoch:142  d_loss:0.5780  g_loss:2.2006
# 1/1 [==============================] - 0s 82ms/step
# epoch:143  d_loss:0.7431  g_loss:2.2495
# 1/1 [==============================] - 0s 89ms/step
# epoch:144  d_loss:0.7491  g_loss:1.2619
# 1/1 [==============================] - 0s 83ms/step
# epoch:145  d_loss:0.8458  g_loss:0.8413
# 1/1 [==============================] - 0s 87ms/step
# epoch:146  d_loss:0.8080  g_loss:0.9774
# 1/1 [==============================] - 0s 83ms/step
# epoch:147  d_loss:0.5616  g_loss:0.9322
# 1/1 [==============================] - 0s 85ms/step
# epoch:148  d_loss:0.7991  g_loss:0.9706
# 1/1 [==============================] - 0s 90ms/step
# epoch:149  d_loss:0.4913  g_loss:1.3738
# 1/1 [==============================] - 0s 83ms/step
# epoch:150  d_loss:0.3905  g_loss:1.7717
# 1/1 [==============================] - 0s 94ms/step
# epoch:151  d_loss:0.4297  g_loss:2.4053
# 1/1 [==============================] - 0s 84ms/step
# epoch:152  d_loss:0.3367  g_loss:2.5395
# 1/1 [==============================] - 0s 85ms/step
# epoch:153  d_loss:0.1990  g_loss:2.8151
# 1/1 [==============================] - 0s 83ms/step
# epoch:154  d_loss:0.2739  g_loss:3.1340
# 1/1 [==============================] - 0s 83ms/step
# epoch:155  d_loss:0.2770  g_loss:3.5455
# 1/1 [==============================] - 0s 84ms/step
# epoch:156  d_loss:0.2063  g_loss:4.1354
# 1/1 [==============================] - 0s 83ms/step
# epoch:157  d_loss:0.2465  g_loss:4.5001
# 1/1 [==============================] - 0s 95ms/step
# epoch:158  d_loss:0.2886  g_loss:4.3822
# 1/1 [==============================] - 0s 82ms/step
# epoch:159  d_loss:0.4370  g_loss:4.2354
# 1/1 [==============================] - 0s 89ms/step
# epoch:160  d_loss:0.3981  g_loss:4.1861
# 1/1 [==============================] - 0s 84ms/step
# epoch:161  d_loss:0.5216  g_loss:3.4737
# 1/1 [==============================] - 0s 83ms/step
# epoch:162  d_loss:0.4914  g_loss:3.5517
# 1/1 [==============================] - 0s 87ms/step
# epoch:163  d_loss:0.4846  g_loss:3.6786
# 1/1 [==============================] - 0s 89ms/step
# epoch:164  d_loss:0.6213  g_loss:3.1174
# 1/1 [==============================] - 0s 84ms/step
# epoch:165  d_loss:0.4916  g_loss:2.7900
# 1/1 [==============================] - 0s 82ms/step
# epoch:166  d_loss:1.0101  g_loss:2.0591
# 1/1 [==============================] - 0s 82ms/step
# epoch:167  d_loss:0.8636  g_loss:2.0420
# 1/1 [==============================] - 0s 82ms/step
# epoch:168  d_loss:0.8885  g_loss:1.9135
# 1/1 [==============================] - 0s 84ms/step
# epoch:169  d_loss:0.8175  g_loss:1.7613
# 1/1 [==============================] - 0s 82ms/step
# epoch:170  d_loss:0.9795  g_loss:1.6053
# 1/1 [==============================] - 0s 82ms/step
# epoch:171  d_loss:0.8633  g_loss:1.2321
# 1/1 [==============================] - 0s 108ms/step
# epoch:172  d_loss:1.0119  g_loss:1.1220
# 1/1 [==============================] - 0s 107ms/step
# epoch:173  d_loss:0.7429  g_loss:1.0340
# 1/1 [==============================] - 0s 104ms/step
# epoch:174  d_loss:0.6535  g_loss:1.1614
# 1/1 [==============================] - 0s 112ms/step
# epoch:175  d_loss:0.6836  g_loss:1.1610
# 1/1 [==============================] - 0s 119ms/step
# epoch:176  d_loss:0.6445  g_loss:1.2609
# 1/1 [==============================] - 0s 109ms/step
# epoch:177  d_loss:0.5397  g_loss:1.2556
# 1/1 [==============================] - 0s 108ms/step
# epoch:178  d_loss:0.3765  g_loss:1.4803
# 1/1 [==============================] - 0s 127ms/step
# epoch:179  d_loss:0.3924  g_loss:1.6170
# 1/1 [==============================] - 0s 137ms/step
# epoch:180  d_loss:0.3800  g_loss:1.7933
# 1/1 [==============================] - 0s 85ms/step
# epoch:181  d_loss:0.4744  g_loss:1.7243
# 1/1 [==============================] - 0s 88ms/step
# epoch:182  d_loss:0.3931  g_loss:1.6206
# 1/1 [==============================] - 0s 97ms/step
# epoch:183  d_loss:0.5066  g_loss:1.5967
# 1/1 [==============================] - 0s 83ms/step
# epoch:184  d_loss:0.4652  g_loss:1.4137
# 1/1 [==============================] - 0s 83ms/step
# epoch:185  d_loss:0.6419  g_loss:1.2347
# 1/1 [==============================] - 0s 83ms/step
# epoch:186  d_loss:0.5131  g_loss:1.4967
# 1/1 [==============================] - 0s 108ms/step
# epoch:187  d_loss:0.4047  g_loss:1.5128
# 1/1 [==============================] - 0s 82ms/step
# epoch:188  d_loss:0.4881  g_loss:1.8709
# 1/1 [==============================] - 0s 82ms/step
# epoch:189  d_loss:0.5971  g_loss:1.4799
# 1/1 [==============================] - 0s 84ms/step
# epoch:190  d_loss:0.6455  g_loss:1.2653
# 1/1 [==============================] - 0s 85ms/step
# epoch:191  d_loss:0.4040  g_loss:1.7343
# 1/1 [==============================] - 0s 82ms/step
# epoch:192  d_loss:0.4520  g_loss:1.3459
# 1/1 [==============================] - 0s 87ms/step
# epoch:193  d_loss:0.4567  g_loss:1.0273
# 1/1 [==============================] - 0s 87ms/step
# epoch:194  d_loss:0.4760  g_loss:1.2730
# 1/1 [==============================] - 0s 83ms/step
# epoch:195  d_loss:0.4406  g_loss:1.4358
# 1/1 [==============================] - 0s 83ms/step
# epoch:196  d_loss:0.3472  g_loss:1.5213
# 1/1 [==============================] - 0s 88ms/step
# epoch:197  d_loss:0.4719  g_loss:1.4650
# 1/1 [==============================] - 0s 86ms/step
# epoch:198  d_loss:0.4836  g_loss:1.3054
# 1/1 [==============================] - 0s 84ms/step
# epoch:199  d_loss:0.5733  g_loss:1.4406
# 1/1 [==============================] - 0s 82ms/step
# epoch:200  d_loss:0.4913  g_loss:1.3332
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 85ms/step
# epoch:201  d_loss:0.4659  g_loss:1.3889
# 1/1 [==============================] - 0s 82ms/step
# epoch:202  d_loss:0.5743  g_loss:1.3398
# 1/1 [==============================] - 0s 82ms/step
# epoch:203  d_loss:0.4523  g_loss:1.2986
# 1/1 [==============================] - 0s 83ms/step
# epoch:204  d_loss:0.6029  g_loss:1.2349
# 1/1 [==============================] - 0s 88ms/step
# epoch:205  d_loss:0.4145  g_loss:1.5293
# 1/1 [==============================] - 0s 82ms/step
# epoch:206  d_loss:0.4835  g_loss:1.5652
# 1/1 [==============================] - 0s 92ms/step
# epoch:207  d_loss:0.6105  g_loss:1.3578
# 1/1 [==============================] - 0s 82ms/step
# epoch:208  d_loss:0.5465  g_loss:1.4120
# 1/1 [==============================] - 0s 83ms/step
# epoch:209  d_loss:0.4982  g_loss:1.3178
# 1/1 [==============================] - 0s 82ms/step
# epoch:210  d_loss:0.5584  g_loss:1.5724
# 1/1 [==============================] - 0s 90ms/step
# epoch:211  d_loss:0.5427  g_loss:1.3118
# 1/1 [==============================] - 0s 86ms/step
# epoch:212  d_loss:0.4702  g_loss:1.8112
# 1/1 [==============================] - 0s 88ms/step
# epoch:213  d_loss:0.6432  g_loss:1.2701
# 1/1 [==============================] - 0s 85ms/step
# epoch:214  d_loss:0.6993  g_loss:1.2854
# 1/1 [==============================] - 0s 82ms/step
# epoch:215  d_loss:0.5068  g_loss:1.6420
# 1/1 [==============================] - 0s 86ms/step
# epoch:216  d_loss:0.4867  g_loss:1.9355
# 1/1 [==============================] - 0s 84ms/step
# epoch:217  d_loss:0.5091  g_loss:1.6952
# 1/1 [==============================] - 0s 86ms/step
# epoch:218  d_loss:0.5826  g_loss:1.5100
# 1/1 [==============================] - 0s 84ms/step
# epoch:219  d_loss:0.4917  g_loss:1.2379
# 1/1 [==============================] - 0s 93ms/step
# epoch:220  d_loss:0.7085  g_loss:1.0449
# 1/1 [==============================] - 0s 83ms/step
# epoch:221  d_loss:0.5345  g_loss:1.3766
# 1/1 [==============================] - 0s 85ms/step
# epoch:222  d_loss:0.6912  g_loss:1.1741
# 1/1 [==============================] - 0s 84ms/step
# epoch:223  d_loss:0.4622  g_loss:1.6833
# 1/1 [==============================] - 0s 83ms/step
# epoch:224  d_loss:0.4831  g_loss:1.7014
# 1/1 [==============================] - 0s 93ms/step
# epoch:225  d_loss:0.5861  g_loss:1.5912
# 1/1 [==============================] - 0s 89ms/step
# epoch:226  d_loss:0.4985  g_loss:1.1899
# 1/1 [==============================] - 0s 85ms/step
# epoch:227  d_loss:0.4278  g_loss:1.4206
# 1/1 [==============================] - 0s 92ms/step
# epoch:228  d_loss:0.4257  g_loss:1.4727
# 1/1 [==============================] - 0s 83ms/step
# epoch:229  d_loss:0.4046  g_loss:1.7627
# 1/1 [==============================] - 0s 82ms/step
# epoch:230  d_loss:0.4172  g_loss:2.2685
# 1/1 [==============================] - 0s 85ms/step
# epoch:231  d_loss:0.4409  g_loss:2.2698
# 1/1 [==============================] - 0s 86ms/step
# epoch:232  d_loss:0.4959  g_loss:1.9944
# 1/1 [==============================] - 0s 81ms/step
# epoch:233  d_loss:0.4057  g_loss:1.6056
# 1/1 [==============================] - 0s 82ms/step
# epoch:234  d_loss:0.3837  g_loss:1.6083
# 1/1 [==============================] - 0s 82ms/step
# epoch:235  d_loss:0.4487  g_loss:1.5657
# 1/1 [==============================] - 0s 83ms/step
# epoch:236  d_loss:0.4198  g_loss:1.7324
# 1/1 [==============================] - 0s 87ms/step
# epoch:237  d_loss:0.4266  g_loss:1.9712
# 1/1 [==============================] - 0s 84ms/step
# epoch:238  d_loss:0.4477  g_loss:1.5714
# 1/1 [==============================] - 0s 81ms/step
# epoch:239  d_loss:0.3491  g_loss:1.6111
# 1/1 [==============================] - 0s 83ms/step
# epoch:240  d_loss:0.4111  g_loss:1.8493
# 1/1 [==============================] - 0s 86ms/step
# epoch:241  d_loss:0.3979  g_loss:1.9721
# 1/1 [==============================] - 0s 83ms/step
# epoch:242  d_loss:0.4212  g_loss:1.6096
# 1/1 [==============================] - 0s 83ms/step
# epoch:243  d_loss:0.4793  g_loss:1.8241
# 1/1 [==============================] - 0s 82ms/step
# epoch:244  d_loss:0.4557  g_loss:1.7153
# 1/1 [==============================] - 0s 84ms/step
# epoch:245  d_loss:0.5515  g_loss:1.5851
# 1/1 [==============================] - 0s 83ms/step
# epoch:246  d_loss:0.5656  g_loss:1.5484
# 1/1 [==============================] - 0s 84ms/step
# epoch:247  d_loss:0.5744  g_loss:1.5990
# 1/1 [==============================] - 0s 92ms/step
# epoch:248  d_loss:0.6520  g_loss:1.7202
# 1/1 [==============================] - 0s 85ms/step
# epoch:249  d_loss:0.5207  g_loss:1.7340
# 1/1 [==============================] - 0s 99ms/step
# epoch:250  d_loss:0.6601  g_loss:1.3732
# 1/1 [==============================] - 0s 83ms/step
# epoch:251  d_loss:0.6456  g_loss:1.3421
# 1/1 [==============================] - 0s 83ms/step
# epoch:252  d_loss:0.5724  g_loss:1.4363
# 1/1 [==============================] - 0s 84ms/step
# epoch:253  d_loss:0.6605  g_loss:1.5386
# 1/1 [==============================] - 0s 83ms/step
# epoch:254  d_loss:0.8548  g_loss:1.5282
# 1/1 [==============================] - 0s 83ms/step
# epoch:255  d_loss:0.7553  g_loss:1.4435
# 1/1 [==============================] - 0s 83ms/step
# epoch:256  d_loss:0.5961  g_loss:1.2355
# 1/1 [==============================] - 0s 105ms/step
# epoch:257  d_loss:0.6248  g_loss:1.3442
# 1/1 [==============================] - 0s 87ms/step
# epoch:258  d_loss:0.6518  g_loss:1.4138
# 1/1 [==============================] - 0s 83ms/step
# epoch:259  d_loss:0.4795  g_loss:1.6321
# 1/1 [==============================] - 0s 83ms/step
# epoch:260  d_loss:0.5915  g_loss:1.5851
# 1/1 [==============================] - 0s 92ms/step
# epoch:261  d_loss:0.6768  g_loss:1.4260
# 1/1 [==============================] - 0s 84ms/step
# epoch:262  d_loss:0.5639  g_loss:1.3964
# 1/1 [==============================] - 0s 88ms/step
# epoch:263  d_loss:0.4497  g_loss:1.5383
# 1/1 [==============================] - 0s 90ms/step
# epoch:264  d_loss:0.4608  g_loss:1.4559
# 1/1 [==============================] - 0s 86ms/step
# epoch:265  d_loss:0.5352  g_loss:1.2869
# 1/1 [==============================] - 0s 84ms/step
# epoch:266  d_loss:0.4670  g_loss:1.6326
# 1/1 [==============================] - 0s 86ms/step
# epoch:267  d_loss:0.4538  g_loss:1.8660
# 1/1 [==============================] - 0s 88ms/step
# epoch:268  d_loss:0.4006  g_loss:2.0385
# 1/1 [==============================] - 0s 91ms/step
# epoch:269  d_loss:0.4004  g_loss:1.9488
# 1/1 [==============================] - 0s 87ms/step
# epoch:270  d_loss:0.4978  g_loss:1.7792
# 1/1 [==============================] - 0s 85ms/step
# epoch:271  d_loss:0.3853  g_loss:1.6683
# 1/1 [==============================] - 0s 85ms/step
# epoch:272  d_loss:0.3665  g_loss:2.0494
# 1/1 [==============================] - 0s 83ms/step
# epoch:273  d_loss:0.2705  g_loss:2.0805
# 1/1 [==============================] - 0s 87ms/step
# epoch:274  d_loss:0.3773  g_loss:1.7770
# 1/1 [==============================] - 0s 90ms/step
# epoch:275  d_loss:0.3025  g_loss:2.4565
# 1/1 [==============================] - 0s 83ms/step
# epoch:276  d_loss:0.4003  g_loss:2.1111
# 1/1 [==============================] - 0s 83ms/step
# epoch:277  d_loss:0.3518  g_loss:2.0275
# 1/1 [==============================] - 0s 88ms/step
# epoch:278  d_loss:0.3946  g_loss:2.1253
# 1/1 [==============================] - 0s 82ms/step
# epoch:279  d_loss:0.4482  g_loss:2.0864
# 1/1 [==============================] - 0s 84ms/step
# epoch:280  d_loss:0.3670  g_loss:1.9744
# 1/1 [==============================] - 0s 84ms/step
# epoch:281  d_loss:0.4187  g_loss:2.1981
# 1/1 [==============================] - 0s 105ms/step
# epoch:282  d_loss:0.5378  g_loss:1.7428
# 1/1 [==============================] - 0s 82ms/step
# epoch:283  d_loss:0.4864  g_loss:1.8343
# 1/1 [==============================] - 0s 85ms/step
# epoch:284  d_loss:0.3631  g_loss:1.7746
# 1/1 [==============================] - 0s 82ms/step
# epoch:285  d_loss:0.6057  g_loss:1.4316
# 1/1 [==============================] - 0s 92ms/step
# epoch:286  d_loss:0.5281  g_loss:1.6220
# 1/1 [==============================] - 0s 84ms/step
# epoch:287  d_loss:0.5149  g_loss:1.7653
# 1/1 [==============================] - 0s 87ms/step
# epoch:288  d_loss:0.5282  g_loss:1.8612
# 1/1 [==============================] - 0s 86ms/step
# epoch:289  d_loss:0.6141  g_loss:1.9246
# 1/1 [==============================] - 0s 83ms/step
# epoch:290  d_loss:0.6292  g_loss:1.6014
# 1/1 [==============================] - 0s 82ms/step
# epoch:291  d_loss:0.6802  g_loss:1.5205
# 1/1 [==============================] - 0s 83ms/step
# epoch:292  d_loss:0.6192  g_loss:1.1449
# 1/1 [==============================] - 0s 98ms/step
# epoch:293  d_loss:0.7174  g_loss:1.0776
# 1/1 [==============================] - 0s 83ms/step
# epoch:294  d_loss:0.7095  g_loss:1.1598
# 1/1 [==============================] - 0s 82ms/step
# epoch:295  d_loss:0.5089  g_loss:1.3243
# 1/1 [==============================] - 0s 81ms/step
# epoch:296  d_loss:0.6174  g_loss:1.1987
# 1/1 [==============================] - 0s 82ms/step
# epoch:297  d_loss:0.6289  g_loss:1.7938
# 1/1 [==============================] - 0s 84ms/step
# epoch:298  d_loss:0.4690  g_loss:1.6498
# 1/1 [==============================] - 0s 83ms/step
# epoch:299  d_loss:0.5875  g_loss:1.6315
# 1/1 [==============================] - 0s 105ms/step
# epoch:300  d_loss:0.5502  g_loss:1.4851
# 1/1 [==============================] - 0s 85ms/step
# epoch:301  d_loss:0.7074  g_loss:1.2535
# 1/1 [==============================] - 0s 83ms/step
# epoch:302  d_loss:0.4727  g_loss:1.5683
# 1/1 [==============================] - 0s 89ms/step
# epoch:303  d_loss:0.3896  g_loss:1.5375
# 1/1 [==============================] - 0s 89ms/step
# epoch:304  d_loss:0.4329  g_loss:1.5957
# 1/1 [==============================] - 0s 84ms/step
# epoch:305  d_loss:0.4378  g_loss:1.5826
# 1/1 [==============================] - 0s 83ms/step
# epoch:306  d_loss:0.4398  g_loss:1.6673
# 1/1 [==============================] - 0s 94ms/step
# epoch:307  d_loss:0.4242  g_loss:1.3808
# 1/1 [==============================] - 0s 84ms/step
# epoch:308  d_loss:0.3853  g_loss:1.8182
# 1/1 [==============================] - 0s 83ms/step
# epoch:309  d_loss:0.4769  g_loss:1.7084
# 1/1 [==============================] - 0s 82ms/step
# epoch:310  d_loss:0.3734  g_loss:1.9646
# 1/1 [==============================] - 0s 83ms/step
# epoch:311  d_loss:0.3367  g_loss:2.1333
# 1/1 [==============================] - 0s 83ms/step
# epoch:312  d_loss:0.5506  g_loss:1.9977
# 1/1 [==============================] - 0s 86ms/step
# epoch:313  d_loss:0.4441  g_loss:1.7065
# 1/1 [==============================] - 0s 99ms/step
# epoch:314  d_loss:0.4445  g_loss:1.2947
# 1/1 [==============================] - 0s 83ms/step
# epoch:315  d_loss:0.6147  g_loss:1.1432
# 1/1 [==============================] - 0s 84ms/step
# epoch:316  d_loss:0.5446  g_loss:1.4305
# 1/1 [==============================] - 0s 82ms/step
# epoch:317  d_loss:0.4426  g_loss:1.7642
# 1/1 [==============================] - 0s 86ms/step
# epoch:318  d_loss:0.5627  g_loss:1.9185
# 1/1 [==============================] - 0s 89ms/step
# epoch:319  d_loss:0.4005  g_loss:1.9640
# 1/1 [==============================] - 0s 84ms/step
# epoch:320  d_loss:0.5287  g_loss:2.1405
# 1/1 [==============================] - 0s 84ms/step
# epoch:321  d_loss:0.3732  g_loss:1.8988
# 1/1 [==============================] - 0s 86ms/step
# epoch:322  d_loss:0.4545  g_loss:1.7516
# 1/1 [==============================] - 0s 83ms/step
# epoch:323  d_loss:0.4861  g_loss:1.7183
# 1/1 [==============================] - 0s 89ms/step
# epoch:324  d_loss:0.3354  g_loss:1.8199
# 1/1 [==============================] - 0s 82ms/step
# epoch:325  d_loss:0.3974  g_loss:2.0868
# 1/1 [==============================] - 0s 83ms/step
# epoch:326  d_loss:0.3654  g_loss:2.1713
# 1/1 [==============================] - 0s 83ms/step
# epoch:327  d_loss:0.4429  g_loss:2.1636
# 1/1 [==============================] - 0s 83ms/step
# epoch:328  d_loss:0.4010  g_loss:1.9972
# 1/1 [==============================] - 0s 86ms/step
# epoch:329  d_loss:0.6627  g_loss:1.8321
# 1/1 [==============================] - 0s 89ms/step
# epoch:330  d_loss:0.4287  g_loss:1.7525
# 1/1 [==============================] - 0s 86ms/step
# epoch:331  d_loss:0.3909  g_loss:2.3123
# 1/1 [==============================] - 0s 88ms/step
# epoch:332  d_loss:0.4585  g_loss:2.1964
# 1/1 [==============================] - 0s 85ms/step
# epoch:333  d_loss:0.4896  g_loss:2.0174
# 1/1 [==============================] - 0s 89ms/step
# epoch:334  d_loss:0.5356  g_loss:2.4116
# 1/1 [==============================] - 0s 85ms/step
# epoch:335  d_loss:0.4853  g_loss:2.2699
# 1/1 [==============================] - 0s 83ms/step
# epoch:336  d_loss:0.5016  g_loss:2.4640
# 1/1 [==============================] - 0s 82ms/step
# epoch:337  d_loss:0.5219  g_loss:1.7886
# 1/1 [==============================] - 0s 84ms/step
# epoch:338  d_loss:0.5372  g_loss:1.7791
# 1/1 [==============================] - 0s 85ms/step
# epoch:339  d_loss:0.5179  g_loss:1.9346
# 1/1 [==============================] - 0s 85ms/step
# epoch:340  d_loss:0.5529  g_loss:2.0145
# 1/1 [==============================] - 0s 88ms/step
# epoch:341  d_loss:0.4632  g_loss:2.1716
# 1/1 [==============================] - 0s 86ms/step
# epoch:342  d_loss:0.5000  g_loss:2.1940
# 1/1 [==============================] - 0s 82ms/step
# epoch:343  d_loss:0.6447  g_loss:1.9990
# 1/1 [==============================] - 0s 82ms/step
# epoch:344  d_loss:0.5362  g_loss:2.0479
# 1/1 [==============================] - 0s 84ms/step
# epoch:345  d_loss:0.5503  g_loss:1.4851
# 1/1 [==============================] - 0s 81ms/step
# epoch:346  d_loss:0.4877  g_loss:1.4941
# 1/1 [==============================] - 0s 83ms/step
# epoch:347  d_loss:0.7136  g_loss:1.5340
# 1/1 [==============================] - 0s 84ms/step
# epoch:348  d_loss:0.4436  g_loss:1.9721
# 1/1 [==============================] - 0s 90ms/step
# epoch:349  d_loss:0.4378  g_loss:2.0190
# 1/1 [==============================] - 0s 83ms/step
# epoch:350  d_loss:0.4969  g_loss:1.9560
# 1/1 [==============================] - 0s 84ms/step
# epoch:351  d_loss:0.4491  g_loss:1.8797
# 1/1 [==============================] - 0s 85ms/step
# epoch:352  d_loss:0.4479  g_loss:2.1340
# 1/1 [==============================] - 0s 104ms/step
# epoch:353  d_loss:0.4773  g_loss:1.8367
# 1/1 [==============================] - 0s 85ms/step
# epoch:354  d_loss:0.4813  g_loss:2.0468
# 1/1 [==============================] - 0s 82ms/step
# epoch:355  d_loss:0.4678  g_loss:2.2954
# 1/1 [==============================] - 0s 89ms/step
# epoch:356  d_loss:0.4061  g_loss:2.2539
# 1/1 [==============================] - 0s 82ms/step
# epoch:357  d_loss:0.2875  g_loss:2.2413
# 1/1 [==============================] - 0s 84ms/step
# epoch:358  d_loss:0.2211  g_loss:2.4235
# 1/1 [==============================] - 0s 90ms/step
# epoch:359  d_loss:0.3760  g_loss:2.0675
# 1/1 [==============================] - 0s 93ms/step
# epoch:360  d_loss:0.3553  g_loss:2.0291
# 1/1 [==============================] - 0s 82ms/step
# epoch:361  d_loss:0.2083  g_loss:2.7255
# 1/1 [==============================] - 0s 89ms/step
# epoch:362  d_loss:0.3011  g_loss:2.9338
# 1/1 [==============================] - 0s 85ms/step
# epoch:363  d_loss:0.2954  g_loss:2.9516
# 1/1 [==============================] - 0s 88ms/step
# epoch:364  d_loss:0.3418  g_loss:2.7026
# 1/1 [==============================] - 0s 83ms/step
# epoch:365  d_loss:0.4648  g_loss:2.4651
# 1/1 [==============================] - 0s 85ms/step
# epoch:366  d_loss:0.2113  g_loss:2.8279
# 1/1 [==============================] - 0s 83ms/step
# epoch:367  d_loss:0.4113  g_loss:2.4700
# 1/1 [==============================] - 0s 82ms/step
# epoch:368  d_loss:0.2477  g_loss:3.2261
# 1/1 [==============================] - 0s 82ms/step
# epoch:369  d_loss:0.4185  g_loss:2.8837
# 1/1 [==============================] - 0s 84ms/step
# epoch:370  d_loss:0.3631  g_loss:1.9937
# 1/1 [==============================] - 0s 95ms/step
# epoch:371  d_loss:0.3398  g_loss:1.6020
# 1/1 [==============================] - 0s 86ms/step
# epoch:372  d_loss:0.3582  g_loss:2.2708
# 1/1 [==============================] - 0s 88ms/step
# epoch:373  d_loss:0.4844  g_loss:1.7619
# 1/1 [==============================] - 0s 82ms/step
# epoch:374  d_loss:0.3990  g_loss:1.6369
# 1/1 [==============================] - 0s 83ms/step
# epoch:375  d_loss:0.5008  g_loss:1.9214
# 1/1 [==============================] - 0s 87ms/step
# epoch:376  d_loss:0.4068  g_loss:2.1533
# 1/1 [==============================] - 0s 85ms/step
# epoch:377  d_loss:0.4454  g_loss:2.7556
# 1/1 [==============================] - 0s 95ms/step
# epoch:378  d_loss:0.4216  g_loss:2.1396
# 1/1 [==============================] - 0s 85ms/step
# epoch:379  d_loss:0.4432  g_loss:1.9721
# 1/1 [==============================] - 0s 86ms/step
# epoch:380  d_loss:0.3796  g_loss:1.7442
# 1/1 [==============================] - 0s 87ms/step
# epoch:381  d_loss:0.4682  g_loss:1.8471
# 1/1 [==============================] - 0s 84ms/step
# epoch:382  d_loss:0.4187  g_loss:2.2119
# 1/1 [==============================] - 0s 84ms/step
# epoch:383  d_loss:0.2737  g_loss:2.5281
# 1/1 [==============================] - 0s 85ms/step
# epoch:384  d_loss:0.6223  g_loss:2.2119
# 1/1 [==============================] - 0s 87ms/step
# epoch:385  d_loss:0.3661  g_loss:2.4628
# 1/1 [==============================] - 0s 89ms/step
# epoch:386  d_loss:0.5295  g_loss:1.7576
# 1/1 [==============================] - 0s 84ms/step
# epoch:387  d_loss:0.4218  g_loss:2.0652
# 1/1 [==============================] - 0s 82ms/step
# epoch:388  d_loss:0.2826  g_loss:2.6162
# 1/1 [==============================] - 0s 90ms/step
# epoch:389  d_loss:0.2731  g_loss:2.6504
# 1/1 [==============================] - 0s 83ms/step
# epoch:390  d_loss:0.4742  g_loss:1.8476
# 1/1 [==============================] - 0s 83ms/step
# epoch:391  d_loss:0.3693  g_loss:1.9745
# 1/1 [==============================] - 0s 82ms/step
# epoch:392  d_loss:0.3672  g_loss:1.4760
# 1/1 [==============================] - 0s 82ms/step
# epoch:393  d_loss:0.3119  g_loss:1.8661
# 1/1 [==============================] - 0s 86ms/step
# epoch:394  d_loss:0.3152  g_loss:2.1625
# 1/1 [==============================] - 0s 82ms/step
# epoch:395  d_loss:0.3190  g_loss:2.1408
# 1/1 [==============================] - 0s 87ms/step
# epoch:396  d_loss:0.2950  g_loss:2.3356
# 1/1 [==============================] - 0s 83ms/step
# epoch:397  d_loss:0.3248  g_loss:2.3466
# 1/1 [==============================] - 0s 88ms/step
# epoch:398  d_loss:0.3917  g_loss:1.9421
# 1/1 [==============================] - 0s 83ms/step
# epoch:399  d_loss:0.3311  g_loss:2.0118
# 1/1 [==============================] - 0s 82ms/step
# epoch:400  d_loss:0.3749  g_loss:1.9730
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 86ms/step
# epoch:401  d_loss:0.4370  g_loss:1.8611
# 1/1 [==============================] - 0s 82ms/step
# epoch:402  d_loss:0.3774  g_loss:2.3618
# 1/1 [==============================] - 0s 85ms/step
# epoch:403  d_loss:0.3204  g_loss:2.4617
# 1/1 [==============================] - 0s 82ms/step
# epoch:404  d_loss:0.3320  g_loss:2.2816
# 1/1 [==============================] - 0s 95ms/step
# epoch:405  d_loss:0.3181  g_loss:2.2995
# 1/1 [==============================] - 0s 86ms/step
# epoch:406  d_loss:0.3049  g_loss:2.0559
# 1/1 [==============================] - 0s 83ms/step
# epoch:407  d_loss:0.3078  g_loss:2.4351
# 1/1 [==============================] - 0s 85ms/step
# epoch:408  d_loss:0.3059  g_loss:2.3705
# 1/1 [==============================] - 0s 86ms/step
# epoch:409  d_loss:0.3106  g_loss:1.8929
# 1/1 [==============================] - 0s 86ms/step
# epoch:410  d_loss:0.3386  g_loss:1.9838
# 1/1 [==============================] - 0s 83ms/step
# epoch:411  d_loss:0.4166  g_loss:1.8984
# 1/1 [==============================] - 0s 83ms/step
# epoch:412  d_loss:0.4063  g_loss:2.0591
# 1/1 [==============================] - 0s 83ms/step
# epoch:413  d_loss:0.1987  g_loss:2.8004
# 1/1 [==============================] - 0s 90ms/step
# epoch:414  d_loss:0.3613  g_loss:2.5162
# 1/1 [==============================] - 0s 83ms/step
# epoch:415  d_loss:0.3635  g_loss:2.2660
# 1/1 [==============================] - 0s 102ms/step
# epoch:416  d_loss:0.4110  g_loss:2.3320
# 1/1 [==============================] - 0s 83ms/step
# epoch:417  d_loss:0.3478  g_loss:2.3311
# 1/1 [==============================] - 0s 88ms/step
# epoch:418  d_loss:0.2588  g_loss:2.4904
# 1/1 [==============================] - 0s 82ms/step
# epoch:419  d_loss:0.3648  g_loss:2.4929
# 1/1 [==============================] - 0s 86ms/step
# epoch:420  d_loss:0.5459  g_loss:2.0588
# 1/1 [==============================] - 0s 83ms/step
# epoch:421  d_loss:0.4668  g_loss:2.0353
# 1/1 [==============================] - 0s 84ms/step
# epoch:422  d_loss:0.4237  g_loss:1.8533
# 1/1 [==============================] - 0s 84ms/step
# epoch:423  d_loss:0.4265  g_loss:2.4078
# 1/1 [==============================] - 0s 83ms/step
# epoch:424  d_loss:0.3382  g_loss:2.5315
# 1/1 [==============================] - 0s 84ms/step
# epoch:425  d_loss:0.3150  g_loss:2.3527
# 1/1 [==============================] - 0s 85ms/step
# epoch:426  d_loss:0.4088  g_loss:2.0472
# 1/1 [==============================] - 0s 113ms/step
# epoch:427  d_loss:0.3082  g_loss:2.2820
# 1/1 [==============================] - 0s 85ms/step
# epoch:428  d_loss:0.2326  g_loss:2.2930
# 1/1 [==============================] - 0s 85ms/step
# epoch:429  d_loss:0.2047  g_loss:2.8584
# 1/1 [==============================] - 0s 84ms/step
# epoch:430  d_loss:0.2848  g_loss:3.0680
# 1/1 [==============================] - 0s 83ms/step
# epoch:431  d_loss:0.3338  g_loss:2.7230
# 1/1 [==============================] - 0s 85ms/step
# epoch:432  d_loss:0.2864  g_loss:2.4405
# 1/1 [==============================] - 0s 86ms/step
# epoch:433  d_loss:0.2372  g_loss:2.0442
# 1/1 [==============================] - 0s 83ms/step
# epoch:434  d_loss:0.1912  g_loss:2.4648
# 1/1 [==============================] - 0s 83ms/step
# epoch:435  d_loss:0.1869  g_loss:2.6266
# 1/1 [==============================] - 0s 83ms/step
# epoch:436  d_loss:0.2950  g_loss:2.5269
# 1/1 [==============================] - 0s 85ms/step
# epoch:437  d_loss:0.2313  g_loss:3.0105
# 1/1 [==============================] - 0s 85ms/step
# epoch:438  d_loss:0.1631  g_loss:2.9647
# 1/1 [==============================] - 0s 83ms/step
# epoch:439  d_loss:0.2592  g_loss:2.5870
# 1/1 [==============================] - 0s 85ms/step
# epoch:440  d_loss:0.2002  g_loss:2.4194
# 1/1 [==============================] - 0s 85ms/step
# epoch:441  d_loss:0.2373  g_loss:2.2350
# 1/1 [==============================] - 0s 94ms/step
# epoch:442  d_loss:0.1738  g_loss:3.0130
# 1/1 [==============================] - 0s 86ms/step
# epoch:443  d_loss:0.2566  g_loss:2.5102
# 1/1 [==============================] - 0s 88ms/step
# epoch:444  d_loss:0.2543  g_loss:2.5127
# 1/1 [==============================] - 0s 87ms/step
# epoch:445  d_loss:0.2524  g_loss:2.3486
# 1/1 [==============================] - 0s 93ms/step
# epoch:446  d_loss:0.2240  g_loss:2.4856
# 1/1 [==============================] - 0s 87ms/step
# epoch:447  d_loss:0.2835  g_loss:2.3119
# 1/1 [==============================] - 0s 85ms/step
# epoch:448  d_loss:0.4052  g_loss:2.3147
# 1/1 [==============================] - 0s 85ms/step
# epoch:449  d_loss:0.2787  g_loss:1.8885
# 1/1 [==============================] - 0s 101ms/step
# epoch:450  d_loss:0.4220  g_loss:1.8460
# 1/1 [==============================] - 0s 84ms/step
# epoch:451  d_loss:0.3187  g_loss:2.7228
# 1/1 [==============================] - 0s 83ms/step
# epoch:452  d_loss:0.3034  g_loss:2.4901
# 1/1 [==============================] - 0s 87ms/step
# epoch:453  d_loss:0.3514  g_loss:2.1850
# 1/1 [==============================] - 0s 95ms/step
# epoch:454  d_loss:0.2911  g_loss:2.0956
# 1/1 [==============================] - 0s 82ms/step
# epoch:455  d_loss:0.5098  g_loss:2.0181
# 1/1 [==============================] - 0s 83ms/step
# epoch:456  d_loss:0.3208  g_loss:2.3442
# 1/1 [==============================] - 0s 87ms/step
# epoch:457  d_loss:0.3603  g_loss:2.1072
# 1/1 [==============================] - 0s 83ms/step
# epoch:458  d_loss:0.3481  g_loss:2.3724
# 1/1 [==============================] - 0s 84ms/step
# epoch:459  d_loss:0.2585  g_loss:3.0263
# 1/1 [==============================] - 0s 83ms/step
# epoch:460  d_loss:0.2693  g_loss:2.4501
# 1/1 [==============================] - 0s 84ms/step
# epoch:461  d_loss:0.2875  g_loss:2.2812
# 1/1 [==============================] - 0s 84ms/step
# epoch:462  d_loss:0.2268  g_loss:2.8238
# 1/1 [==============================] - 0s 84ms/step
# epoch:463  d_loss:0.2581  g_loss:2.3013
# 1/1 [==============================] - 0s 85ms/step
# epoch:464  d_loss:0.2593  g_loss:2.1325
# 1/1 [==============================] - 0s 87ms/step
# epoch:465  d_loss:0.2609  g_loss:2.8123
# 1/1 [==============================] - 0s 82ms/step
# epoch:466  d_loss:0.2362  g_loss:2.4566
# 1/1 [==============================] - 0s 83ms/step
# epoch:467  d_loss:0.3168  g_loss:2.4157
# 1/1 [==============================] - 0s 84ms/step
# epoch:468  d_loss:0.2222  g_loss:2.4254
# 1/1 [==============================] - 0s 102ms/step
# epoch:469  d_loss:0.3568  g_loss:2.5314
# 1/1 [==============================] - 0s 84ms/step
# epoch:470  d_loss:0.2990  g_loss:2.6655
# 1/1 [==============================] - 0s 85ms/step
# epoch:471  d_loss:0.2705  g_loss:2.5453
# 1/1 [==============================] - 0s 88ms/step
# epoch:472  d_loss:0.2584  g_loss:2.5274
# 1/1 [==============================] - 0s 84ms/step
# epoch:473  d_loss:0.1584  g_loss:3.0150
# 1/1 [==============================] - 0s 89ms/step
# epoch:474  d_loss:0.2043  g_loss:3.1645
# 1/1 [==============================] - 0s 83ms/step
# epoch:475  d_loss:0.1747  g_loss:2.9010
# 1/1 [==============================] - 0s 82ms/step
# epoch:476  d_loss:0.2633  g_loss:2.4456
# 1/1 [==============================] - 0s 83ms/step
# epoch:477  d_loss:0.1879  g_loss:2.7566
# 1/1 [==============================] - 0s 84ms/step
# epoch:478  d_loss:0.1815  g_loss:2.8034
# 1/1 [==============================] - 0s 83ms/step
# epoch:479  d_loss:0.2679  g_loss:2.6009
# 1/1 [==============================] - 0s 83ms/step
# epoch:480  d_loss:0.3606  g_loss:2.1064
# 1/1 [==============================] - 0s 84ms/step
# epoch:481  d_loss:0.2756  g_loss:2.2278
# 1/1 [==============================] - 0s 87ms/step
# epoch:482  d_loss:0.2664  g_loss:2.5329
# 1/1 [==============================] - 0s 86ms/step
# epoch:483  d_loss:0.2184  g_loss:3.1329
# 1/1 [==============================] - 0s 84ms/step
# epoch:484  d_loss:0.2744  g_loss:3.5098
# 1/1 [==============================] - 0s 83ms/step
# epoch:485  d_loss:0.2301  g_loss:2.4504
# 1/1 [==============================] - 0s 84ms/step
# epoch:486  d_loss:0.3868  g_loss:2.0413
# 1/1 [==============================] - 0s 85ms/step
# epoch:487  d_loss:0.3946  g_loss:1.9531
# 1/1 [==============================] - 0s 101ms/step
# epoch:488  d_loss:0.2024  g_loss:2.2744
# 1/1 [==============================] - 0s 87ms/step
# epoch:489  d_loss:0.1764  g_loss:3.2075
# 1/1 [==============================] - 0s 171ms/step
# epoch:490  d_loss:0.2769  g_loss:3.0397
# 1/1 [==============================] - 0s 163ms/step
# epoch:491  d_loss:0.2296  g_loss:3.1189
# 1/1 [==============================] - 0s 87ms/step
# epoch:492  d_loss:0.2722  g_loss:2.5649
# 1/1 [==============================] - 0s 98ms/step
# epoch:493  d_loss:0.2148  g_loss:2.5389
# 1/1 [==============================] - 0s 87ms/step
# epoch:494  d_loss:0.1833  g_loss:2.3025
# 1/1 [==============================] - 0s 91ms/step
# epoch:495  d_loss:0.2443  g_loss:2.5596
# 1/1 [==============================] - 0s 84ms/step
# epoch:496  d_loss:0.1909  g_loss:2.9457
# 1/1 [==============================] - 0s 87ms/step
# epoch:497  d_loss:0.2982  g_loss:2.5392
# 1/1 [==============================] - 0s 84ms/step
# epoch:498  d_loss:0.2953  g_loss:2.5666
# 1/1 [==============================] - 0s 89ms/step
# epoch:499  d_loss:0.2516  g_loss:1.9209
# 1/1 [==============================] - 0s 84ms/step
# epoch:500  d_loss:0.2088  g_loss:2.3610
# 1/1 [==============================] - 0s 84ms/step
# epoch:501  d_loss:0.2359  g_loss:2.7125
# 1/1 [==============================] - 0s 83ms/step
# epoch:502  d_loss:0.2255  g_loss:2.7061
# 1/1 [==============================] - 0s 88ms/step
# epoch:503  d_loss:0.2363  g_loss:2.3567
# 1/1 [==============================] - 0s 86ms/step
# epoch:504  d_loss:0.3799  g_loss:2.3588
# 1/1 [==============================] - 0s 84ms/step
# epoch:505  d_loss:0.2560  g_loss:2.5298
# 1/1 [==============================] - 0s 85ms/step
# epoch:506  d_loss:0.2102  g_loss:2.3434
# 1/1 [==============================] - 0s 87ms/step
# epoch:507  d_loss:0.2951  g_loss:2.5155
# 1/1 [==============================] - 0s 83ms/step
# epoch:508  d_loss:0.2445  g_loss:2.6982
# 1/1 [==============================] - 0s 84ms/step
# epoch:509  d_loss:0.2212  g_loss:2.9128
# 1/1 [==============================] - 0s 84ms/step
# epoch:510  d_loss:0.1660  g_loss:3.1668
# 1/1 [==============================] - 0s 86ms/step
# epoch:511  d_loss:0.2382  g_loss:2.7234
# 1/1 [==============================] - 0s 92ms/step
# epoch:512  d_loss:0.2159  g_loss:2.4057
# 1/1 [==============================] - 0s 84ms/step
# epoch:513  d_loss:0.2575  g_loss:2.4921
# 1/1 [==============================] - 0s 86ms/step
# epoch:514  d_loss:0.1985  g_loss:2.5564
# 1/1 [==============================] - 0s 83ms/step
# epoch:515  d_loss:0.2701  g_loss:2.3429
# 1/1 [==============================] - 0s 93ms/step
# epoch:516  d_loss:0.2314  g_loss:2.6336
# 1/1 [==============================] - 0s 84ms/step
# epoch:517  d_loss:0.2308  g_loss:2.6920
# 1/1 [==============================] - 0s 86ms/step
# epoch:518  d_loss:0.1841  g_loss:2.7713
# 1/1 [==============================] - 0s 87ms/step
# epoch:519  d_loss:0.1919  g_loss:2.6850
# 1/1 [==============================] - 0s 86ms/step
# ...
# 1/1 [==============================] - 0s 83ms/step
# epoch:1830  d_loss:0.4487  g_loss:1.1361
# 1/1 [==============================] - 0s 86ms/step
# epoch:1831  d_loss:0.4521  g_loss:1.6456
# 1/1 [==============================] - 0s 88ms/step
# epoch:1832  d_loss:0.6496  g_loss:1.7255
# 1/1 [==============================] - 0s 83ms/step
# epoch:1833  d_loss:0.4826  g_loss:1.7814
# 1/1 [==============================] - 0s 90ms/step
# epoch:1834  d_loss:0.5473  g_loss:1.6942
# 1/1 [==============================] - 0s 86ms/step
# epoch:1835  d_loss:0.4848  g_loss:1.3933
# 1/1 [==============================] - 0s 90ms/step
# epoch:1836  d_loss:0.4399  g_loss:1.5302
# 1/1 [==============================] - 0s 85ms/step
# epoch:1837  d_loss:0.4472  g_loss:1.5620
# 1/1 [==============================] - 0s 86ms/step
# epoch:1838  d_loss:0.5489  g_loss:1.2937
# 1/1 [==============================] - 0s 91ms/step
# epoch:1839  d_loss:0.5428  g_loss:1.6308
# 1/1 [==============================] - 0s 85ms/step
# epoch:1840  d_loss:0.6309  g_loss:1.2524
# 1/1 [==============================] - 0s 82ms/step
# epoch:1841  d_loss:0.5655  g_loss:1.5471
# 1/1 [==============================] - 0s 87ms/step
# epoch:1842  d_loss:0.5109  g_loss:1.7503
# 1/1 [==============================] - 0s 85ms/step
# epoch:1843  d_loss:0.4956  g_loss:1.8129
# 1/1 [==============================] - 0s 83ms/step
# epoch:1844  d_loss:0.5363  g_loss:1.9556
# 1/1 [==============================] - 0s 85ms/step
# epoch:1845  d_loss:0.6704  g_loss:1.4338
# 1/1 [==============================] - 0s 83ms/step
# epoch:1846  d_loss:0.5085  g_loss:1.4411
# 1/1 [==============================] - 0s 83ms/step
# epoch:1847  d_loss:0.6096  g_loss:1.2787
# 1/1 [==============================] - 0s 85ms/step
# epoch:1848  d_loss:0.6352  g_loss:1.2705
# 1/1 [==============================] - 0s 89ms/step
# epoch:1849  d_loss:0.5935  g_loss:1.3879
# 1/1 [==============================] - 0s 86ms/step
# epoch:1850  d_loss:0.4738  g_loss:1.6865
# 1/1 [==============================] - 0s 83ms/step
# epoch:1851  d_loss:0.4127  g_loss:2.2181
# 1/1 [==============================] - 0s 84ms/step
# epoch:1852  d_loss:0.5520  g_loss:1.9886
# 1/1 [==============================] - 0s 89ms/step
# epoch:1853  d_loss:0.6255  g_loss:1.9605
# 1/1 [==============================] - 0s 82ms/step
# epoch:1854  d_loss:0.5166  g_loss:1.4918
# 1/1 [==============================] - 0s 83ms/step
# epoch:1855  d_loss:0.5252  g_loss:1.2245
# 1/1 [==============================] - 0s 84ms/step
# epoch:1856  d_loss:0.4167  g_loss:1.1763
# 1/1 [==============================] - 0s 85ms/step
# epoch:1857  d_loss:0.3792  g_loss:1.5308
# 1/1 [==============================] - 0s 83ms/step
# epoch:1858  d_loss:0.4284  g_loss:1.7874
# 1/1 [==============================] - 0s 82ms/step
# epoch:1859  d_loss:0.5205  g_loss:1.5554
# 1/1 [==============================] - 0s 90ms/step
# epoch:1860  d_loss:0.3800  g_loss:2.0149
# 1/1 [==============================] - 0s 87ms/step
# epoch:1861  d_loss:0.4324  g_loss:1.8608
# 1/1 [==============================] - 0s 87ms/step
# epoch:1862  d_loss:0.5147  g_loss:1.6511
# 1/1 [==============================] - 0s 83ms/step
# epoch:1863  d_loss:0.5266  g_loss:1.1830
# 1/1 [==============================] - 0s 83ms/step
# epoch:1864  d_loss:0.4172  g_loss:1.3896
# 1/1 [==============================] - 0s 84ms/step
# epoch:1865  d_loss:0.7023  g_loss:1.3353
# 1/1 [==============================] - 0s 89ms/step
# epoch:1866  d_loss:0.5071  g_loss:1.4739
# 1/1 [==============================] - 0s 83ms/step
# epoch:1867  d_loss:0.5000  g_loss:1.4983
# 1/1 [==============================] - 0s 83ms/step
# epoch:1868  d_loss:0.4629  g_loss:2.1516
# 1/1 [==============================] - 0s 83ms/step
# epoch:1869  d_loss:0.6949  g_loss:1.6213
# 1/1 [==============================] - 0s 89ms/step
# epoch:1870  d_loss:0.5097  g_loss:1.6340
# 1/1 [==============================] - 0s 83ms/step
# epoch:1871  d_loss:0.5379  g_loss:1.5283
# 1/1 [==============================] - 0s 85ms/step
# epoch:1872  d_loss:0.4661  g_loss:1.3168
# 1/1 [==============================] - 0s 84ms/step
# epoch:1873  d_loss:0.5337  g_loss:1.0841
# 1/1 [==============================] - 0s 86ms/step
# epoch:1874  d_loss:0.5974  g_loss:1.1397
# 1/1 [==============================] - 0s 83ms/step
# epoch:1875  d_loss:0.5616  g_loss:1.5585
# 1/1 [==============================] - 0s 83ms/step
# epoch:1876  d_loss:0.5666  g_loss:1.6197
# 1/1 [==============================] - 0s 91ms/step
# epoch:1877  d_loss:0.5972  g_loss:1.5577
# 1/1 [==============================] - 0s 93ms/step
# epoch:1878  d_loss:0.3977  g_loss:1.8111
# 1/1 [==============================] - 0s 88ms/step
# epoch:1879  d_loss:0.5025  g_loss:1.7680
# 1/1 [==============================] - 0s 84ms/step
# epoch:1880  d_loss:0.4271  g_loss:1.4242
# 1/1 [==============================] - 0s 84ms/step
# epoch:1881  d_loss:0.5287  g_loss:1.3465
# 1/1 [==============================] - 0s 96ms/step
# epoch:1882  d_loss:0.4151  g_loss:1.5619
# 1/1 [==============================] - 0s 94ms/step
# epoch:1883  d_loss:0.5409  g_loss:1.5810
# 1/1 [==============================] - 0s 89ms/step
# epoch:1884  d_loss:0.4098  g_loss:1.5298
# 1/1 [==============================] - 0s 86ms/step
# epoch:1885  d_loss:0.5629  g_loss:1.6873
# 1/1 [==============================] - 0s 85ms/step
# epoch:1886  d_loss:0.4839  g_loss:1.7426
# 1/1 [==============================] - 0s 82ms/step
# epoch:1887  d_loss:0.4804  g_loss:1.4337
# 1/1 [==============================] - 0s 92ms/step
# epoch:1888  d_loss:0.5641  g_loss:1.3905
# 1/1 [==============================] - 0s 82ms/step
# epoch:1889  d_loss:0.6236  g_loss:1.6569
# 1/1 [==============================] - 0s 91ms/step
# epoch:1890  d_loss:0.4997  g_loss:1.5424
# 1/1 [==============================] - 0s 87ms/step
# epoch:1891  d_loss:0.5552  g_loss:1.5965
# 1/1 [==============================] - 0s 87ms/step
# epoch:1892  d_loss:0.5486  g_loss:1.6313
# 1/1 [==============================] - 0s 82ms/step
# epoch:1893  d_loss:0.6451  g_loss:1.5016
# 1/1 [==============================] - 0s 95ms/step
# epoch:1894  d_loss:0.5702  g_loss:1.4226
# 1/1 [==============================] - 0s 82ms/step
# epoch:1895  d_loss:0.5130  g_loss:1.4121
# 1/1 [==============================] - 0s 82ms/step
# epoch:1896  d_loss:0.6507  g_loss:1.2335
# 1/1 [==============================] - 0s 86ms/step
# epoch:1897  d_loss:0.6061  g_loss:1.4372
# 1/1 [==============================] - 0s 94ms/step
# epoch:1898  d_loss:0.6069  g_loss:1.5136
# 1/1 [==============================] - 0s 85ms/step
# epoch:1899  d_loss:0.5497  g_loss:1.6919
# 1/1 [==============================] - 0s 85ms/step
# epoch:1900  d_loss:0.4694  g_loss:1.3145
# 1/1 [==============================] - 0s 85ms/step
# epoch:1901  d_loss:0.4133  g_loss:1.4714
# 1/1 [==============================] - 0s 105ms/step
# epoch:1902  d_loss:0.4308  g_loss:1.4270
# 1/1 [==============================] - 0s 89ms/step
# epoch:1903  d_loss:0.5158  g_loss:1.2209
# 1/1 [==============================] - 0s 85ms/step
# epoch:1904  d_loss:0.5346  g_loss:1.4573
# 1/1 [==============================] - 0s 84ms/step
# epoch:1905  d_loss:0.5584  g_loss:1.8176
# 1/1 [==============================] - 0s 83ms/step
# epoch:1906  d_loss:0.5453  g_loss:1.7958
# 1/1 [==============================] - 0s 84ms/step
# epoch:1907  d_loss:0.5246  g_loss:1.7934
# 1/1 [==============================] - 0s 89ms/step
# epoch:1908  d_loss:0.4970  g_loss:1.7391
# 1/1 [==============================] - 0s 83ms/step
# epoch:1909  d_loss:0.4511  g_loss:1.6355
# 1/1 [==============================] - 0s 85ms/step
# epoch:1910  d_loss:0.5649  g_loss:1.3890
# 1/1 [==============================] - 0s 83ms/step
# epoch:1911  d_loss:0.4215  g_loss:1.6524
# 1/1 [==============================] - 0s 82ms/step
# epoch:1912  d_loss:0.5213  g_loss:1.5921
# 1/1 [==============================] - 0s 85ms/step
# epoch:1913  d_loss:0.4894  g_loss:1.5944
# 1/1 [==============================] - 0s 83ms/step
# epoch:1914  d_loss:0.4753  g_loss:1.6302
# 1/1 [==============================] - 0s 86ms/step
# epoch:1915  d_loss:0.3990  g_loss:1.5119
# 1/1 [==============================] - 0s 87ms/step
# epoch:1916  d_loss:0.3724  g_loss:1.9365
# 1/1 [==============================] - 0s 140ms/step
# epoch:1917  d_loss:0.3437  g_loss:1.9266
# 1/1 [==============================] - 0s 164ms/step
# epoch:1918  d_loss:0.4113  g_loss:1.9991
# 1/1 [==============================] - 0s 156ms/step
# epoch:1919  d_loss:0.5803  g_loss:1.4790
# 1/1 [==============================] - 0s 94ms/step
# epoch:1920  d_loss:0.5058  g_loss:1.0674
# 1/1 [==============================] - 0s 88ms/step
# epoch:1921  d_loss:0.4526  g_loss:1.3701
# 1/1 [==============================] - 0s 83ms/step
# epoch:1922  d_loss:0.5704  g_loss:1.3417
# 1/1 [==============================] - 0s 83ms/step
# epoch:1923  d_loss:0.4165  g_loss:1.6032
# 1/1 [==============================] - 0s 84ms/step
# epoch:1924  d_loss:0.5814  g_loss:0.9525
# 1/1 [==============================] - 0s 84ms/step
# epoch:1925  d_loss:0.4604  g_loss:1.6160
# 1/1 [==============================] - 0s 83ms/step
# epoch:1926  d_loss:0.4571  g_loss:1.7471
# 1/1 [==============================] - 0s 91ms/step
# epoch:1927  d_loss:0.4002  g_loss:1.9053
# 1/1 [==============================] - 0s 83ms/step
# epoch:1928  d_loss:0.5230  g_loss:1.5574
# 1/1 [==============================] - 0s 83ms/step
# epoch:1929  d_loss:0.5715  g_loss:1.1467
# 1/1 [==============================] - 0s 83ms/step
# epoch:1930  d_loss:0.5502  g_loss:1.0346
# 1/1 [==============================] - 0s 84ms/step
# epoch:1931  d_loss:0.4350  g_loss:1.5185
# 1/1 [==============================] - 0s 83ms/step
# epoch:1932  d_loss:0.5433  g_loss:1.6090
# 1/1 [==============================] - 0s 85ms/step
# epoch:1933  d_loss:0.5614  g_loss:1.4635
# 1/1 [==============================] - 0s 82ms/step
# epoch:1934  d_loss:0.5623  g_loss:1.3064
# 1/1 [==============================] - 0s 90ms/step
# epoch:1935  d_loss:0.5166  g_loss:1.5528
# 1/1 [==============================] - 0s 82ms/step
# epoch:1936  d_loss:0.6173  g_loss:1.1412
# 1/1 [==============================] - 0s 84ms/step
# epoch:1937  d_loss:0.5588  g_loss:1.3098
# 1/1 [==============================] - 0s 82ms/step
# epoch:1938  d_loss:0.6853  g_loss:1.3171
# 1/1 [==============================] - 0s 92ms/step
# epoch:1939  d_loss:0.7603  g_loss:1.4217
# 1/1 [==============================] - 0s 87ms/step
# epoch:1940  d_loss:0.4917  g_loss:1.6581
# 1/1 [==============================] - 0s 83ms/step
# epoch:1941  d_loss:0.4778  g_loss:1.6546
# 1/1 [==============================] - 0s 84ms/step
# epoch:1942  d_loss:0.5923  g_loss:1.3843
# 1/1 [==============================] - 0s 94ms/step
# epoch:1943  d_loss:0.4231  g_loss:1.6072
# 1/1 [==============================] - 0s 83ms/step
# epoch:1944  d_loss:0.5413  g_loss:1.4425
# 1/1 [==============================] - 0s 83ms/step
# epoch:1945  d_loss:0.4969  g_loss:1.1572
# 1/1 [==============================] - 0s 86ms/step
# epoch:1946  d_loss:0.5000  g_loss:1.2789
# 1/1 [==============================] - 0s 100ms/step
# epoch:1947  d_loss:0.4054  g_loss:1.6035
# 1/1 [==============================] - 0s 84ms/step
# epoch:1948  d_loss:0.4475  g_loss:1.3870
# 1/1 [==============================] - 0s 83ms/step
# epoch:1949  d_loss:0.5301  g_loss:1.2079
# 1/1 [==============================] - 0s 84ms/step
# epoch:1950  d_loss:0.4727  g_loss:1.9434
# 1/1 [==============================] - 0s 88ms/step
# epoch:1951  d_loss:0.4219  g_loss:1.7983
# 1/1 [==============================] - 0s 90ms/step
# epoch:1952  d_loss:0.4853  g_loss:1.4193
# 1/1 [==============================] - 0s 83ms/step
# epoch:1953  d_loss:0.5012  g_loss:1.4838
# 1/1 [==============================] - 0s 83ms/step
# epoch:1954  d_loss:0.4812  g_loss:1.5409
# 1/1 [==============================] - 0s 83ms/step
# epoch:1955  d_loss:0.4436  g_loss:1.3837
# 1/1 [==============================] - 0s 84ms/step
# epoch:1956  d_loss:0.4091  g_loss:1.7813
# 1/1 [==============================] - 0s 85ms/step
# epoch:1957  d_loss:0.5353  g_loss:1.8189
# 1/1 [==============================] - 0s 86ms/step
# epoch:1958  d_loss:0.4623  g_loss:1.7226
# 1/1 [==============================] - 0s 89ms/step
# epoch:1959  d_loss:0.4807  g_loss:1.4759
# 1/1 [==============================] - 0s 83ms/step
# epoch:1960  d_loss:0.5465  g_loss:1.3503
# 1/1 [==============================] - 0s 84ms/step
# epoch:1961  d_loss:0.4237  g_loss:1.3165
# 1/1 [==============================] - 0s 93ms/step
# epoch:1962  d_loss:0.5465  g_loss:1.6735
# 1/1 [==============================] - 0s 92ms/step
# epoch:1963  d_loss:0.4833  g_loss:1.9818
# 1/1 [==============================] - 0s 84ms/step
# epoch:1964  d_loss:0.4382  g_loss:1.8869
# 1/1 [==============================] - 0s 83ms/step
# epoch:1965  d_loss:0.5610  g_loss:1.6292
# 1/1 [==============================] - 0s 88ms/step
# epoch:1966  d_loss:0.5160  g_loss:1.3654
# 1/1 [==============================] - 0s 85ms/step
# epoch:1967  d_loss:0.4195  g_loss:1.6658
# 1/1 [==============================] - 0s 85ms/step
# epoch:1968  d_loss:0.6805  g_loss:1.4219
# 1/1 [==============================] - 0s 84ms/step
# epoch:1969  d_loss:0.4427  g_loss:1.5264
# 1/1 [==============================] - 0s 82ms/step
# epoch:1970  d_loss:0.5599  g_loss:1.5410
# 1/1 [==============================] - 0s 86ms/step
# epoch:1971  d_loss:0.6124  g_loss:1.3762
# 1/1 [==============================] - 0s 83ms/step
# epoch:1972  d_loss:0.4854  g_loss:1.4582
# 1/1 [==============================] - 0s 85ms/step
# epoch:1973  d_loss:0.7966  g_loss:1.3981
# 1/1 [==============================] - 0s 102ms/step
# epoch:1974  d_loss:0.6174  g_loss:1.3614
# 1/1 [==============================] - 0s 84ms/step
# epoch:1975  d_loss:0.5075  g_loss:1.2718
# 1/1 [==============================] - 0s 88ms/step
# epoch:1976  d_loss:0.5318  g_loss:1.3284
# 1/1 [==============================] - 0s 83ms/step
# epoch:1977  d_loss:0.6013  g_loss:1.1687
# 1/1 [==============================] - 0s 84ms/step
# epoch:1978  d_loss:0.5597  g_loss:1.4976
# 1/1 [==============================] - 0s 89ms/step
# epoch:1979  d_loss:0.6700  g_loss:1.4521
# 1/1 [==============================] - 0s 86ms/step
# epoch:1980  d_loss:0.4776  g_loss:1.6316
# 1/1 [==============================] - 0s 85ms/step
# epoch:1981  d_loss:0.7614  g_loss:1.2325
# 1/1 [==============================] - 0s 84ms/step
# epoch:1982  d_loss:0.5187  g_loss:1.2334
# 1/1 [==============================] - 0s 84ms/step
# epoch:1983  d_loss:0.5986  g_loss:1.6513
# 1/1 [==============================] - 0s 92ms/step
# epoch:1984  d_loss:0.4448  g_loss:1.8108
# 1/1 [==============================] - 0s 87ms/step
# epoch:1985  d_loss:0.5336  g_loss:2.1087
# 1/1 [==============================] - 0s 86ms/step
# epoch:1986  d_loss:0.4864  g_loss:1.8114
# 1/1 [==============================] - 0s 89ms/step
# epoch:1987  d_loss:0.4519  g_loss:1.7688
# 1/1 [==============================] - 0s 87ms/step
# epoch:1988  d_loss:0.4912  g_loss:1.6734
# 1/1 [==============================] - 0s 82ms/step
# epoch:1989  d_loss:0.4419  g_loss:1.2784
# 1/1 [==============================] - 0s 90ms/step
# epoch:1990  d_loss:0.4132  g_loss:1.4528
# 1/1 [==============================] - 0s 92ms/step
# epoch:1991  d_loss:0.5224  g_loss:1.4820
# 1/1 [==============================] - 0s 82ms/step
# epoch:1992  d_loss:0.5438  g_loss:1.7239
# 1/1 [==============================] - 0s 84ms/step
# epoch:1993  d_loss:0.4515  g_loss:1.5174
# 1/1 [==============================] - 0s 83ms/step
# epoch:1994  d_loss:0.4862  g_loss:1.4654
# 1/1 [==============================] - 0s 84ms/step
# epoch:1995  d_loss:0.5160  g_loss:1.6887
# 1/1 [==============================] - 0s 87ms/step
# epoch:1996  d_loss:0.5877  g_loss:1.4661
# 1/1 [==============================] - 0s 91ms/step
# epoch:1997  d_loss:0.4259  g_loss:1.5192
# 1/1 [==============================] - 0s 84ms/step
# epoch:1998  d_loss:0.4598  g_loss:1.3613
# 1/1 [==============================] - 0s 84ms/step
# epoch:1999  d_loss:0.3224  g_loss:1.8320
# 1/1 [==============================] - 0s 91ms/step
# epoch:2000  d_loss:0.5936  g_loss:1.6346
# 1/1 [==============================] - 0s 74ms/step
