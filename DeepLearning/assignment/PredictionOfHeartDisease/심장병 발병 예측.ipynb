# %%
#
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

import pandas as pd

#랜덤시드3
import random
random.seed(3)

targetUrl_heartDiseaseClassificationDataset="https://raw.githubusercontent.com/Minon98/Python/main/heart%20disease%20classification%20dataset.csv"
df = pd.read_csv(targetUrl_heartDiseaseClassificationDataset)

df
# Out:
#      Unnamed: 0  age     sex  cp  trestbps   chol  fbs  restecg  thalach  \
# 0             0   63    male   3     145.0  233.0    1        0    150.0
# 1             1   37    male   2     130.0  250.0    0        1    187.0
# 2             2   41  female   1     130.0  204.0    0        0    172.0
# 3             3   56    male   1     120.0  236.0    0        1    178.0
# 4             4   57  female   0       NaN  354.0    0        1    163.0
# ..          ...  ...     ...  ..       ...    ...  ...      ...      ...
# 298         298   57  female   0     140.0  241.0    0        1    123.0
# 299         299   45    male   3     110.0  264.0    0        1    132.0
# 300         300   68    male   0     144.0  193.0    1        1    141.0
# 301         301   57    male   0       NaN  131.0    0        1    115.0
# 302         302   57  female   1     130.0  236.0    0        0    174.0
#
#      exang  oldpeak  slope  ca  thal target
# 0        0      2.3      0   0     1    yes
# 1        0      3.5      0   0     2    yes
# 2        0      1.4      2   0     2    yes
# 3        0      0.8      2   0     2    yes
# 4        1      0.6      2   0     2    yes
# ..     ...      ...    ...  ..   ...    ...
# 298      1      0.2      1   0     3     no
# 299      0      1.2      1   0     3     no
# 300      0      3.4      1   2     3     no
# 301      1      1.2      1   1     3     no
# 302      0      0.0      1   1     2     no
#
# [303 rows x 15 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# age             int64
# sex            object
# cp              int64
# trestbps      float64
# chol          float64
# fbs             int64
# restecg         int64
# thalach       float64
# exang           int64
# oldpeak       float64
# slope           int64
# ca              int64
# thal            int64
# target         object
# dtype: object

# %%
#결측치 측정
df.isnull().sum().sort_values(ascending=False)
# Out:
# thalach       5
# trestbps      4
# chol          1
# Unnamed: 0    0
# age           0
# sex           0
# cp            0
# fbs           0
# restecg       0
# exang         0
# oldpeak       0
# slope         0
# ca            0
# thal          0
# target        0
# dtype: int64

# %%
#결측치 평균으로 채우기
df=df.fillna(df.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
#sex , target one-hot encoding
df = pd.get_dummies(df)
df
# Out:
#      Unnamed: 0  age  cp    trestbps   chol  fbs  restecg  thalach  exang  \
# 0             0   63   3  145.000000  233.0    1        0    150.0      0
# 1             1   37   2  130.000000  250.0    0        1    187.0      0
# 2             2   41   1  130.000000  204.0    0        0    172.0      0
# 3             3   56   1  120.000000  236.0    0        1    178.0      0
# 4             4   57   0  131.712375  354.0    0        1    163.0      1
# ..          ...  ...  ..         ...    ...  ...      ...      ...    ...
# 298         298   57   0  140.000000  241.0    0        1    123.0      1
# 299         299   45   3  110.000000  264.0    0        1    132.0      0
# 300         300   68   0  144.000000  193.0    1        1    141.0      0
# 301         301   57   0  131.712375  131.0    0        1    115.0      1
# 302         302   57   1  130.000000  236.0    0        0    174.0      0
#
#      oldpeak  slope  ca  thal  sex_female  sex_male  target_no  target_yes
# 0        2.3      0   0     1           0         1          0           1
# 1        3.5      0   0     2           0         1          0           1
# 2        1.4      2   0     2           1         0          0           1
# 3        0.8      2   0     2           0         1          0           1
# 4        0.6      2   0     2           1         0          0           1
# ..       ...    ...  ..   ...         ...       ...        ...         ...
# 298      0.2      1   0     3           1         0          1           0
# 299      1.2      1   0     3           0         1          1           0
# 300      3.4      1   2     3           0         1          1           0
# 301      1.2      1   1     3           0         1          1           0
# 302      0.0      1   1     2           1         0          1           0
#
# [303 rows x 17 columns]

# %%
# standardization을 위한 object type 제거
df_scale = df.copy()
df_scale.drop(['sex_female', 'sex_male', 'target_no', 'target_yes'], axis=1, inplace=True)
df_scale
# Out:
#      Unnamed: 0  age  cp    trestbps   chol  fbs  restecg  thalach  exang  \
# 0             0   63   3  145.000000  233.0    1        0    150.0      0
# 1             1   37   2  130.000000  250.0    0        1    187.0      0
# 2             2   41   1  130.000000  204.0    0        0    172.0      0
# 3             3   56   1  120.000000  236.0    0        1    178.0      0
# 4             4   57   0  131.712375  354.0    0        1    163.0      1
# ..          ...  ...  ..         ...    ...  ...      ...      ...    ...
# 298         298   57   0  140.000000  241.0    0        1    123.0      1
# 299         299   45   3  110.000000  264.0    0        1    132.0      0
# 300         300   68   0  144.000000  193.0    1        1    141.0      0
# 301         301   57   0  131.712375  131.0    0        1    115.0      1
# 302         302   57   1  130.000000  236.0    0        0    174.0      0
#
#      oldpeak  slope  ca  thal
# 0        2.3      0   0     1
# 1        3.5      0   0     2
# 2        1.4      2   0     2
# 3        0.8      2   0     2
# 4        0.6      2   0     2
# ..       ...    ...  ..   ...
# 298      0.2      1   0     3
# 299      1.2      1   0     3
# 300      3.4      1   2     3
# 301      1.2      1   1     3
# 302      0.0      1   1     2
#
# [303 rows x 13 columns]

# %%
#자료 standardization
scaler = StandardScaler()
scaler.fit(df_scale)
df_scaled = scaler.transform(df_scale)
df_scaled = pd.DataFrame(data=df_scaled, columns=df_scale.columns)
print(df_scaled)
# Out:
#      Unnamed: 0       age        cp      trestbps      chol       fbs  \
# 0     -1.726344  0.952197  1.973123  7.600324e-01 -0.257417  2.394438
# 1     -1.714911 -1.915313  1.002577 -9.794528e-02  0.071170 -0.417635
# 2     -1.703478 -1.474158  0.032031 -9.794528e-02 -0.817947 -0.417635
# 3     -1.692046  0.180175  0.032031 -6.699304e-01 -0.199431 -0.417635
# 4     -1.680613  0.290464 -0.938515 -1.625679e-15  2.081349 -0.417635
# ..          ...       ...       ...           ...       ...       ...
# 298    1.680613  0.290464 -0.938515  4.740398e-01 -0.102787 -0.417635
# 299    1.692046 -1.033002  1.973123 -1.241915e+00  0.341771 -0.417635
# 300    1.703478  1.503641 -0.938515  7.028339e-01 -1.030562  2.394438
# 301    1.714911  0.290464 -0.938515 -1.625679e-15 -2.228938 -0.417635
# 302    1.726344  0.290464  0.032031 -9.794528e-02 -0.199431 -0.417635
#
#       restecg   thalach     exang   oldpeak     slope        ca      thal
# 0   -1.005832  0.006009 -0.696631  1.087338 -2.274579 -0.714429 -2.148873
# 1    0.898962  1.662292 -0.696631  2.122573 -2.274579 -0.714429 -0.512922
# 2   -1.005832  0.990826 -0.696631  0.310912  0.976352 -0.714429 -0.512922
# 3    0.898962  1.259413 -0.696631 -0.206705  0.976352 -0.714429 -0.512922
# 4    0.898962  0.587946  1.435481 -0.379244  0.976352 -0.714429 -0.512922
# ..        ...       ...       ...       ...       ...       ...       ...
# 298  0.898962 -1.202631  1.435481 -0.724323 -0.649113 -0.714429  1.123029
# 299  0.898962 -0.799751 -0.696631  0.138373 -0.649113 -0.714429  1.123029
# 300  0.898962 -0.396871 -0.696631  2.036303 -0.649113  1.244593  1.123029
# 301  0.898962 -1.560746  1.435481  0.138373 -0.649113  0.265082  1.123029
# 302 -1.005832  1.080355 -0.696631 -0.896862 -0.649113  0.265082 -0.512922
#
# [303 rows x 13 columns]

# %%
#원핫인코딩된 성별 합치기
df_heart = pd.concat([df_scaled,df['sex_male']],axis=1)
df_heart = pd.concat([df_heart,df['sex_female']],axis=1)
df_heart.columns
# Out:
# Index(['Unnamed: 0', 'age', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'sex_male',
#        'sex_female'],
#       dtype='object')

# %%
#모델 구성
X = df_heart.iloc[:, 1:16]
y = df.iloc[:, 14:16]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)        #test dataset 10%

model = Sequential()
model.add(Dense(32, input_dim=14, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 32)                480
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_22 (Dense)            (None, 16)                528
#
#  dropout_15 (Dropout)        (None, 16)                0
#
#  dense_23 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 1,042
# Trainable params: 1,042
# Non-trainable params: 0
# _________________________________________________________________

# %%
#earlystopping 20번마다 val_acc가 나아지지 않으면 멈춤 - 제일 좋은 val_acc 저장
es = EarlyStopping(monitor='val_accuracy',verbose = 1, patience = 20, mode = 'max')
mc = ModelCheckpoint('/content/drive/My Drive/Heart.h5', monitor='val_accuracy', mode='max', save_best_only=True, verbose = 1)

# %%
history= model.fit(X_train, y_train, epochs=2000, batch_size=10, validation_split=0.2, callbacks=[es, mc]) #validation 20%
# Out:
# Epoch 1/2000
# 22/22 [==============================] - ETA: 0s - loss: 0.9379 - accuracy: 0.5945
# Epoch 1: val_accuracy improved from -inf to 0.69091, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 1s 15ms/step - loss: 0.9379 - accuracy: 0.5945 - val_loss: 0.7805 - val_accuracy: 0.6909
# Epoch 2/2000
#  1/22 [>.............................] - ETA: 0s - loss: 0.7374 - accuracy: 0.6000
# Epoch 2: val_accuracy improved from 0.69091 to 0.74545, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8567 - accuracy: 0.6636 - val_loss: 0.7520 - val_accuracy: 0.7455
# Epoch 3/2000
#  1/22 [>.............................] - ETA: 0s - loss: 0.7273 - accuracy: 0.7000
# Epoch 3: val_accuracy did not improve from 0.74545
# 22/22 [==============================] - 0s 4ms/step - loss: 0.8576 - accuracy: 0.7189 - val_loss: 0.7331 - val_accuracy: 0.7455
# Epoch 4/2000
#  1/22 [>.............................] - ETA: 0s - loss: 1.0326 - accuracy: 0.7000
# Epoch 4: val_accuracy improved from 0.74545 to 0.76364, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8180 - accuracy: 0.7143 - val_loss: 0.7197 - val_accuracy: 0.7636
# Epoch 5/2000
#  1/22 [>.............................] - ETA: 0s - loss: 1.5612 - accuracy: 0.8000
# Epoch 5: val_accuracy did not improve from 0.76364
# 22/22 [==============================] - 0s 5ms/step - loss: 0.8095 - accuracy: 0.6636 - val_loss: 0.7104 - val_accuracy: 0.7455
# Epoch 6/2000
#  1/22 [>.............................] - ETA: 0s - loss: 0.5675 - accuracy: 1.0000
# Epoch 6: val_accuracy improved from 0.76364 to 0.80000, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 0s 6ms/step - loss: 0.8140 - accuracy: 0.6912 - val_loss: 0.6999 - val_accuracy: 0.8000
# Epoch 7/2000
#  1/22 [>.............................] - ETA: 0s - loss: 0.6631 - accuracy: 0.9000
# Epoch 7: val_accuracy improved from 0.80000 to 0.83636, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 0s 6ms/step - loss: 0.8018 - accuracy: 0.7419 - val_loss: 0.6921 - val_accuracy: 0.8364
# Epoch 8/2000
#  1/22 [>.............................] - ETA: 0s - loss: 0.7624 - accuracy: 0.6000
# Epoch 8: val_accuracy improved from 0.83636 to 0.85455, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 0s 6ms/step - loss: 0.8331 - accuracy: 0.6774 - val_loss: 0.6886 - val_accuracy: 0.8545
# Epoch 9/2000
#  1/22 [>.............................] - ETA: 0s - loss: 1.1550 - accuracy: 0.7000
# Epoch 9: val_accuracy did not improve from 0.85455
# 22/22 [==============================] - 0s 4ms/step - loss: 0.9372 - accuracy: 0.6959 - val_loss: 0.6837 - val_accuracy: 0.8364
# Epoch 10/2000
#  1/22 [>.............................] - ETA: 0s - loss: 0.6560 - accuracy: 0.7000
# Epoch 10: val_accuracy improved from 0.85455 to 0.89091, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 0s 6ms/step - loss: 0.9508 - accuracy: 0.7558 - val_loss: 0.6792 - val_accuracy: 0.8909
# Epoch 11/2000
#  1/22 [>.............................] - ETA: 0s - loss: 1.0926 - accuracy: 0.8000
# Epoch 11: val_accuracy did not improve from 0.89091
# 22/22 [==============================] - 0s 4ms/step - loss: 1.0458 - accuracy: 0.7051 - val_loss: 0.6804 - val_accuracy: 0.8364
# Epoch 12/2000
#  1/22 [>.............................] - ETA: 0s - loss: 0.6270 - accuracy: 0.8000
# Epoch 12: val_accuracy did not improve from 0.89091
# 22/22 [==============================] - 0s 4ms/step - loss: 1.0090 - accuracy: 0.7189 - val_loss: 0.6753 - val_accuracy: 0.8182
# Epoch 13/2000
#  1/22 [>.............................] - ETA: 0s - loss: 0.9117 - accuracy: 0.8000
# Epoch 13: val_accuracy did not improve from 0.89091
# 22/22 [==============================] - 0s 4ms/step - loss: 1.2159 - accuracy: 0.7005 - val_loss: 0.6772 - val_accuracy: 0.8545
# Epoch 14/2000
# 20/22 [==========================>...] - ETA: 0s - loss: 1.2655 - accuracy: 0.7000
# Epoch 14: val_accuracy improved from 0.89091 to 0.94545, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 0s 6ms/step - loss: 1.2656 - accuracy: 0.7051 - val_loss: 0.7180 - val_accuracy: 0.9455
# Epoch 15/2000
#  1/22 [>.............................] - ETA: 0s - loss: 1.8687 - accuracy: 0.5000
# Epoch 15: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 1.4664 - accuracy: 0.6728 - val_loss: 0.6720 - val_accuracy: 0.8727
# Epoch 16/2000
#  1/22 [>.............................] - ETA: 0s - loss: 3.9895 - accuracy: 0.6000
# Epoch 16: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 1.7689 - accuracy: 0.7189 - val_loss: 0.6840 - val_accuracy: 0.7273
# Epoch 17/2000
#  1/22 [>.............................] - ETA: 0s - loss: 2.1684 - accuracy: 0.6000
# Epoch 17: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 2.1354 - accuracy: 0.6820 - val_loss: 0.7576 - val_accuracy: 0.6727
# Epoch 18/2000
#  1/22 [>.............................] - ETA: 0s - loss: 1.1419 - accuracy: 0.6000
# Epoch 18: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 2.4331 - accuracy: 0.6313 - val_loss: 0.6876 - val_accuracy: 0.7636
# Epoch 19/2000
#  1/22 [>.............................] - ETA: 0s - loss: 2.9365 - accuracy: 0.5000
# Epoch 19: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 2.6787 - accuracy: 0.6728 - val_loss: 0.6969 - val_accuracy: 0.9455
# Epoch 20/2000
#  1/22 [>.............................] - ETA: 0s - loss: 4.3443 - accuracy: 0.6000
# Epoch 20: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 3ms/step - loss: 3.5052 - accuracy: 0.6820 - val_loss: 0.7104 - val_accuracy: 0.7636
# Epoch 21/2000
#  1/22 [>.............................] - ETA: 0s - loss: 7.6009 - accuracy: 0.6000
# Epoch 21: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 3.4124 - accuracy: 0.6636 - val_loss: 0.9793 - val_accuracy: 0.6909
# Epoch 22/2000
# 19/22 [========================>.....] - ETA: 0s - loss: 3.7794 - accuracy: 0.6000
# Epoch 22: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 3.6401 - accuracy: 0.5899 - val_loss: 1.0212 - val_accuracy: 0.6909
# Epoch 23/2000
#  1/22 [>.............................] - ETA: 0s - loss: 5.4269 - accuracy: 0.6000
# Epoch 23: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 5.9953 - accuracy: 0.6544 - val_loss: 0.6762 - val_accuracy: 0.9091
# Epoch 24/2000
# 20/22 [==========================>...] - ETA: 0s - loss: 5.6117 - accuracy: 0.6050
# Epoch 24: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 5ms/step - loss: 5.5443 - accuracy: 0.6129 - val_loss: 1.3204 - val_accuracy: 0.6545
# Epoch 25/2000
# 22/22 [==============================] - ETA: 0s - loss: 7.0252 - accuracy: 0.6267
# Epoch 25: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 7.0252 - accuracy: 0.6267 - val_loss: 0.9377 - val_accuracy: 0.7091
# Epoch 26/2000
#  1/22 [>.............................] - ETA: 0s - loss: 2.7688 - accuracy: 0.6000
# Epoch 26: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 6.0489 - accuracy: 0.6037 - val_loss: 0.7054 - val_accuracy: 0.7455
# Epoch 27/2000
#  1/22 [>.............................] - ETA: 0s - loss: 15.6505 - accuracy: 0.6000
# Epoch 27: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 6.8703 - accuracy: 0.6129 - val_loss: 0.7586 - val_accuracy: 0.7273
# Epoch 28/2000
# 20/22 [==========================>...] - ETA: 0s - loss: 8.8071 - accuracy: 0.6150
# Epoch 28: val_accuracy did not improve from 0.94545
# 22/22 [==============================] - 0s 4ms/step - loss: 8.9893 - accuracy: 0.5945 - val_loss: 0.8871 - val_accuracy: 0.7273
# Epoch 29/2000
#  1/22 [>.............................] - ETA: 0s - loss: 12.4363 - accuracy: 0.8000
# Epoch 29: val_accuracy improved from 0.94545 to 0.96364, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 0s 5ms/step - loss: 10.0903 - accuracy: 0.5806 - val_loss: 0.9672 - val_accuracy: 0.9636
# Epoch 30/2000
#  1/22 [>.............................] - ETA: 0s - loss: 9.1955 - accuracy: 0.6000
# Epoch 30: val_accuracy improved from 0.96364 to 0.98182, saving model to /content/drive/My Drive/Heart.h5
# 22/22 [==============================] - 0s 6ms/step - loss: 9.5748 - accuracy: 0.6313 - val_loss: 0.8324 - val_accuracy: 0.9818
# Epoch 31/2000
#  1/22 [>.............................] - ETA: 0s - loss: 28.0234 - accuracy: 0.5000
# Epoch 31: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 12.5955 - accuracy: 0.5714 - val_loss: 2.1484 - val_accuracy: 0.9636
# Epoch 32/2000
#  1/22 [>.............................] - ETA: 0s - loss: 6.3180 - accuracy: 0.6000
# Epoch 32: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 12.3107 - accuracy: 0.6682 - val_loss: 3.3981 - val_accuracy: 0.5455
# Epoch 33/2000
#  1/22 [>.............................] - ETA: 0s - loss: 6.0220 - accuracy: 0.4000
# Epoch 33: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 12.4275 - accuracy: 0.5346 - val_loss: 2.6863 - val_accuracy: 0.6000
# Epoch 34/2000
# 17/22 [======================>.......] - ETA: 0s - loss: 12.8123 - accuracy: 0.5471
# Epoch 34: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 5ms/step - loss: 14.7314 - accuracy: 0.5714 - val_loss: 0.9394 - val_accuracy: 0.9636
# Epoch 35/2000
#  1/22 [>.............................] - ETA: 0s - loss: 14.9817 - accuracy: 0.8000
# Epoch 35: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 3ms/step - loss: 14.0959 - accuracy: 0.5530 - val_loss: 1.8963 - val_accuracy: 0.6545
# Epoch 36/2000
#  1/22 [>.............................] - ETA: 0s - loss: 15.0898 - accuracy: 0.6000
# Epoch 36: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 13.7396 - accuracy: 0.6175 - val_loss: 1.2845 - val_accuracy: 0.9636
# Epoch 37/2000
#  1/22 [>.............................] - ETA: 0s - loss: 18.6575 - accuracy: 0.5000
# Epoch 37: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 19.4737 - accuracy: 0.5576 - val_loss: 0.9420 - val_accuracy: 0.7455
# Epoch 38/2000
#  1/22 [>.............................] - ETA: 0s - loss: 15.2400 - accuracy: 0.6000
# Epoch 38: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 20.3798 - accuracy: 0.6129 - val_loss: 0.7432 - val_accuracy: 0.6545
# Epoch 39/2000
#  1/22 [>.............................] - ETA: 0s - loss: 13.8216 - accuracy: 0.6000
# Epoch 39: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 20.4705 - accuracy: 0.5069 - val_loss: 1.4496 - val_accuracy: 0.7091
# Epoch 40/2000
# 21/22 [===========================>..] - ETA: 0s - loss: 22.3857 - accuracy: 0.6238
# Epoch 40: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 5ms/step - loss: 22.6133 - accuracy: 0.6083 - val_loss: 0.8640 - val_accuracy: 0.7455
# Epoch 41/2000
#  1/22 [>.............................] - ETA: 0s - loss: 29.9829 - accuracy: 0.6000
# Epoch 41: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 21.8011 - accuracy: 0.5714 - val_loss: 2.6116 - val_accuracy: 0.9091
# Epoch 42/2000
#  1/22 [>.............................] - ETA: 0s - loss: 23.2905 - accuracy: 0.7000
# Epoch 42: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 23.4896 - accuracy: 0.5899 - val_loss: 5.4562 - val_accuracy: 0.5455
# Epoch 43/2000
#  1/22 [>.............................] - ETA: 0s - loss: 16.9412 - accuracy: 0.5000
# Epoch 43: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 25.0401 - accuracy: 0.4793 - val_loss: 1.0218 - val_accuracy: 0.7455
# Epoch 44/2000
#  1/22 [>.............................] - ETA: 0s - loss: 74.0334 - accuracy: 0.5000
# Epoch 44: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 25.7124 - accuracy: 0.5668 - val_loss: 1.5344 - val_accuracy: 0.9636
# Epoch 45/2000
#  1/22 [>.............................] - ETA: 0s - loss: 23.0261 - accuracy: 0.6000
# Epoch 45: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 26.9918 - accuracy: 0.5668 - val_loss: 5.5642 - val_accuracy: 0.4727
# Epoch 46/2000
# 14/22 [==================>...........] - ETA: 0s - loss: 35.3157 - accuracy: 0.5071
# Epoch 46: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 5ms/step - loss: 27.6500 - accuracy: 0.5392 - val_loss: 0.7085 - val_accuracy: 0.9273
# Epoch 47/2000
#  1/22 [>.............................] - ETA: 0s - loss: 19.9872 - accuracy: 0.5000
# Epoch 47: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 26.9850 - accuracy: 0.5161 - val_loss: 3.4394 - val_accuracy: 0.5818
# Epoch 48/2000
#  1/22 [>.............................] - ETA: 0s - loss: 5.0526 - accuracy: 0.6000
# Epoch 48: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 29.2400 - accuracy: 0.5300 - val_loss: 4.2994 - val_accuracy: 0.6000
# Epoch 49/2000
#  1/22 [>.............................] - ETA: 0s - loss: 21.8108 - accuracy: 0.6000
# Epoch 49: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 31.2098 - accuracy: 0.5484 - val_loss: 1.2242 - val_accuracy: 0.6364
# Epoch 50/2000
#  1/22 [>.............................] - ETA: 0s - loss: 11.4649 - accuracy: 0.7000
# Epoch 50: val_accuracy did not improve from 0.98182
# 22/22 [==============================] - 0s 4ms/step - loss: 35.7061 - accuracy: 0.5346 - val_loss: 3.7847 - val_accuracy: 0.9636
# Epoch 50: early stopping

# %%
ls
# Out:
#  assets/             Heart.h5            saved_model.pb
# 'Colab Notebooks'/   keras_metadata.pb   variables/

# %%
#저장된 모델을 가져와 모델을 테스트셋에 적용해 정확도를 구합니다. 

#Model 불러오기
from tensorflow.python.keras.models import load_model
model = load_model('Heart.h5')

score=model.evaluate(X_test, y_test, batch_size= 10)
print('test_loss: ' , score[0])
print('test_accuracy: ', score[1])
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9897 - accuracy: 0.9355
# test_loss:  0.9897136688232422
# test_accuracy:  0.9354838728904724

# %% [markdown]
# ## 변화
# - 1차
# test_loss:  0.8526384234428406
# test_accuracy:  0.774193525314331
# - 2차
# test_loss:  0.8885266780853271
# test_accuracy:  0.8387096524238586
# - 3차
# test_loss:  1.4293769598007202
# test_accuracy:  0.8387096524238586
# - 4차
# test_loss:  1.1191447973251343
# test_accuracy:  0.9032257795333862
# - 5차
# test_loss:  0.9897136688232422
# test_accuracy:  0.9354838728904724

# %%
#시각화 - 과적합 확인
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
