# %% [markdown]
# - 구간 [0,2]에서 함수 f(x) = x^2 + sin(3x+7) 함수의 그래프

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,2)
y = x**2 + np.sin(3*x+7)

plt.plot(x, y)
plt.show()

# %% [markdown]
# - Gradient descent를 실습하려고 합니다. 아래 코드를 변형하여 학생이 원하는 함수, 범위, 시작점, 학습률로 실행하여 보세요.

# %%
#값 수정

import numpy as np
import matplotlib.pyplot as plt
#import math
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return -a * b * np.exp(-a**2 - b**2)                                          ##

def grad_f(a,b): # gradient
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0] # to store all thetas
	theta = theta0     # initial values for thetas
	# main loop by iterations:
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1]) #함수 f(x,y)의 gradient
		# update parameters:
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-0.5, 0.25], iters =50, alpha = 0.07)             ##

# f(x,y) = x^2 + y^2 함수의 그래프 그리기
fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')
#plt.hold(True)
a = np.arange(-3, 3, 0.25)                                                      ##
b = np.arange(-3, 3, 0.25)                                                      ##
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.5,                ##
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
## c= 0 ## 최소값을 찾기 위한 부분
ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')

##plt.axis('equal')

plt.show()
# Out:
# [ 0.09145195  0.08360413  0.07540296  0.06688005  0.05807136  0.04901604
#   0.03975515  0.03033042  0.0207833   0.01115426  0.0014825  -0.00819398
#  -0.01783799 -0.02741269 -0.03688105 -0.04620552 -0.055348   -0.0642701
#  -0.07293391 -0.08130289 -0.08934305 -0.09702417 -0.10432084 -0.11121331
#  -0.11768807 -0.12373796 -0.12936208 -0.13456529 -0.13935757 -0.14375321
#  -0.1477699  -0.15142788 -0.15474908 -0.15775642 -0.16047312 -0.16292222
#  -0.16512616 -0.16710645 -0.1688835  -0.17047644 -0.17190305 -0.17317977
#  -0.17432167 -0.17534251 -0.17625481 -0.17706988 -0.17779797 -0.17844828
#  -0.17902909 -0.17954784 -0.18001117]

# %% [markdown]
# seaborn을 이용한 시각화

# %%
import pandas as pd
import seaborn as sns

targetUrl_caffeine="https://raw.githubusercontent.com/Minon98/Python/main/caffeine.csv"

caffeineData = pd.read_csv(targetUrl_caffeine)

sns.set_theme()
sns.set(rc={"figure.dpi":300})
sns.set(rc={"figure.figsize":(6,3)})


## Scatter plot 산점도

sns.scatterplot(x="Volume (ml)", y ="Caffeine (mg)", data=caffeineData, hue ='type')

# %%
sns.histplot( y="Caffeine (mg)", data = caffeineData)

# %%
sns.histplot( x="Volume (ml)", data = caffeineData)

# %%
sns.histplot( x= "Volume (ml)", data = caffeineData, kde = "True")

# %%
sns.histplot( x= "Volume (ml)", data = caffeineData, hue = "type")

# %%
plt.figure(figsize=(15,5))
sns.barplot(x="type", y="Caffeine (mg)", data =caffeineData)

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="type", y="Volume (ml)", data=caffeineData)
