# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
#  assets/             data/      keras_metadata.pb   saved_model.pb   variables/
# 'Colab Notebooks'/   Heart.h5   MNIST_CNN.hdf5      smile/

# %%
from tensorflow.python.keras.models import load_model
model = load_model('Heart.h5')

score=model.evaluate(X_test, y_test, batch_size= 10)
print('test_loss: ' , score[0])
print('test_accuracy: ', score[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e31471065d41> in <module>
#       2 model = load_model('Heart.h5')
#       3
# ----> 4 score=model.evaluate(X_test, y_test, batch_size= 10)
#       5 print('test_loss: ' , score[0])
#       6 print('test_accuracy: ', score[1])
#
# NameError: name 'X_test' is not defined
